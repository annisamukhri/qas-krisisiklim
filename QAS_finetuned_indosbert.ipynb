# %%
# !pip install datasets
# !pip install transformers==4.45.2
# !pip install -U sentence-transformers
# !pip install wandb
# Out:
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 6.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 2.5 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 8.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 7.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0
# Collecting transformers==4.45.2
#   Downloading transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (0.5.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.2)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (2025.1.31)
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 23.2 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 19.8 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
# Successfully installed tokenizers-0.20.3 transformers-4.45.2
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.45.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.29.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.8)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.10.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.23.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
import os
import pickle
import pandas as pd
import time
import logging
import json
import torch
import re
import numpy as np
import nltk
from sentence_transformers import (SentenceTransformer, SentenceTransformerTrainer, SentenceTransformerTrainingArguments, util)
from sentence_transformers.losses import MultipleNegativesRankingLoss
from sentence_transformers.training_args import BatchSamplers
from sentence_transformers.datasets import NoDuplicatesDataLoader
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from transformers import AutoTokenizer, AutoModel, BertTokenizer, BertModel
from datasets import Dataset, load_dataset, DatasetDict, concatenate_datasets
from sklearn.model_selection import train_test_split
from tqdm.autonotebook import tqdm, trange
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity

# %%
import wandb
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset

# %%
dataset_path_1 = '/content/drive/MyDrive/myData/dataset/dataset1.csv'
dataset_path_2 = '/content/drive/MyDrive/myData/dataset/dataset2.csv'

df1 = pd.read_csv(dataset_path_1)
df2 = pd.read_csv(dataset_path_2)

df = pd.concat([df1, df2], ignore_index=True)
df = df.drop(df.columns[-1],axis=1)
df
# Out:
#                                                question  \
# 0     Apakah Kita Memahami Perubahan Iklim Lebih Bai...
# 1                 Di Mana Perubahan Iklim Paling Nyata?
# 2     Apa yang Dapat Diajarkan Iklim Masa Lalu kepad...
# 3     Suhu Bumi Pernah Berubah Sebelumnya. Bagaimana...
# 4                            Apa Bukti Perubahan Iklim?
# ...                                                 ...
# 9225  Apa nama konsep yang melihat perubahan iklim s...
# 9226  Apa saja masalah operasional yang dihadapi saa...
# 9227       Apa tujuan dari standar Rainforest Alliance?
# 9228  Apa saja kebutuhan makanan hewan herbivora dal...
# 9229  Tindakan apa yang telah diterapkan pemerintah ...
#
#                                                  answer
# 0     Ya, jauh lebih baik. Laporan IPCC pertama, yan...
# 1     Tanda-tanda perubahan iklim tidak dapat dipung...
# 2     Di masa lalu, Bumi telah mengalami periode ber...
# 3     Meskipun iklim dapat dicirikan oleh banyak var...
# 4     Kita telah lama mengamati perubahan iklim kita...
# ...                                                 ...
# 9225  Mengurangi jarak psikologis tidak secara andal...
# 9226  Beberapa masalah operasional yang dilaporkan t...
# 9227  Standar Rainforest Alliance bertujuan untuk me...
# 9228  Kebutuhan makanan hewan herbivora dalam petern...
# 9229  Pemerintah Washington D.C. telah menerapkan be...
#
# [9230 rows x 2 columns]

# %% [markdown]
# # Pre-processing data

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('indonesian'))

def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def case_folding(text):
    return text.lower()

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

def preprocess_text(text):
    text = clean_text(text)
    text = case_folding(text)
    text = remove_stopwords(text)
    return text

data = df.copy()
data['question'] = data['question'].apply(preprocess_text)
data['answer'] = data['answer'].apply(preprocess_text)
data
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                                question  \
# 0            memahami perubahan iklim dibandingkan ipcc
# 1                                 perubahan iklim nyata
# 2                                       diajarkan iklim
# 3            suhu bumi berubah pemanasan global berbeda
# 4                                 bukti perubahan iklim
# ...                                                 ...
# 9225  nama konsep perubahan iklim mengakibatkan aksi...
# 9226  operasional dihadapi minyak sayur bahan bakar ...
# 9227                 tujuan standar rainforest alliance
# 9228       kebutuhan makanan hewan herbivora peternakan
# 9229  tindakan diterapkan pemerintah washington dc m...
#
#                                                  answer
# 0     ya laporan ipcc dirilis 1990 menyimpulkan peru...
# 1     tandatanda perubahan iklim dipungkiri skala gl...
# 2     bumi mengalami periode berkepanjangan peningka...
# 3     iklim dicirikan variabel suhu indikator utama ...
# 4     mengamati perubahan iklim ilmuwan pengamatan m...
# ...                                                 ...
# 9225  mengurangi jarak psikologis andal meningkatkan...
# 9226  operasional dilaporkan terkait penggunaan miny...
# 9227  standar rainforest alliance bertujuan melestar...
# 9228  kebutuhan makanan hewan herbivora peternakan d...
# 9229  pemerintah washington dc menerapkan langkah me...
#
# [9230 rows x 2 columns]

# %% [markdown]
# # Split dataset

# %%
train_data, temp_data = train_test_split(data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# %%
dataset = DatasetDict({
    "train": Dataset.from_pandas(train_data.reset_index(drop=True)),
    "val": Dataset.from_pandas(val_data.reset_index(drop=True)),
    "test": Dataset.from_pandas(test_data.reset_index(drop=True))
})

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 6461
#     })
#     val: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 1384
#     })
#     test: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 1385
#     })
# })

# %%
train_dataset = dataset["train"]
eval_dataset = dataset["val"]
test_dataset = dataset["test"]
train_dataset
# Out:
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 6461
# })

# %% [markdown]
# # Finetuning indoSBERT model

# %%
# 1. Load a model to finetune with
model = SentenceTransformer('denaya/indoSBERT-large')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.23k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/709k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.05M [00:00<?, ?B/s]

# %%
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 1024, 'out_features': 256, 'bias': True, 'activation_function': 'torch.nn.modules.activation.Tanh'})
# )

# %%
# 2. Load a dataset to finetune on
train_dataset = dataset["train"]
eval_dataset = dataset["val"]
test_dataset = dataset["test"]

# 3. Define a loss function
loss = MultipleNegativesRankingLoss(model)

# 4. Specify training arguments
args = SentenceTransformerTrainingArguments(
    # Required parameter:
    output_dir="models/denaya-indoSBERT-large_e5b16",
    # training parameters:
    num_train_epochs=5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    warmup_ratio=0.1,
    # MultipleNegativesRankingLoss benefits from no duplicate samples in a batch
    batch_sampler=BatchSamplers.NO_DUPLICATES,
    fp16=True,  # Set to False if you get an error that your GPU can't run on FP16
    bf16=False,  # Set to True if you have a GPU that supports BF16
    # tracking/debugging parameters:
    eval_strategy="steps",
    eval_steps=100,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=2,
    logging_steps=100,
    run_name="indoSBERT-large_e5bs16",  # Will be used in W&B if `wandb` is installed
)

# %%
# 5. Create an evaluator & evaluate the base model
corpus = {str(idx): answer for idx, answer in enumerate(dataset["val"]["answer"])}
queries = {str(idx): question for idx, question in enumerate(dataset["val"]["question"])}
relevant_docs = {str(idx): {str(idx)} for idx in range(len(dataset["val"]["question"]))}

dev_evaluator = InformationRetrievalEvaluator(
    queries=queries,
    corpus=corpus,
    relevant_docs=relevant_docs,
    name="indoSBERT-large-eval",
)
dev_evaluator(model)
# Out:
# {'indoSBERT-large-eval_cosine_accuracy@1': 0.48627167630057805,
#  'indoSBERT-large-eval_cosine_accuracy@3': 0.6329479768786127,
#  'indoSBERT-large-eval_cosine_accuracy@5': 0.684971098265896,
#  'indoSBERT-large-eval_cosine_accuracy@10': 0.7601156069364162,
#  'indoSBERT-large-eval_cosine_precision@1': 0.48627167630057805,
#  'indoSBERT-large-eval_cosine_precision@3': 0.21098265895953758,
#  'indoSBERT-large-eval_cosine_precision@5': 0.13699421965317918,
#  'indoSBERT-large-eval_cosine_precision@10': 0.07601156069364161,
#  'indoSBERT-large-eval_cosine_recall@1': 0.48627167630057805,
#  'indoSBERT-large-eval_cosine_recall@3': 0.6329479768786127,
#  'indoSBERT-large-eval_cosine_recall@5': 0.684971098265896,
#  'indoSBERT-large-eval_cosine_recall@10': 0.7601156069364162,
#  'indoSBERT-large-eval_cosine_ndcg@10': 0.6183852893298069,
#  'indoSBERT-large-eval_cosine_mrr@10': 0.5737329686209749,
#  'indoSBERT-large-eval_cosine_map@100': 0.5805544119423703}

# %%
# 6. Create a trainer & train
trainer = SentenceTransformerTrainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    loss=loss,
    evaluator=dev_evaluator,
)
trainer.train()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: 1122am (1122am-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241210_034529-871j7b3u</code>
# Syncing run <strong><a href='https://wandb.ai/1122am-university/sentence-transformers/runs/871j7b3u' target="_blank">indoSBERT-large_e5bs16</a></strong> to <a href='https://wandb.ai/1122am-university/sentence-transformers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1122am-university/sentence-transformers' target="_blank">https://wandb.ai/1122am-university/sentence-transformers</a>
#  View run at <a href='https://wandb.ai/1122am-university/sentence-transformers/runs/871j7b3u' target="_blank">https://wandb.ai/1122am-university/sentence-transformers/runs/871j7b3u</a>
#     <div>
#
#       <progress value='2020' max='2020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2020/2020 33:00, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>
td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.000700</td>
#       <td>0.065356</td>
#       <td>0.831647</td>
#       <td>0.915462</td>
#       <td>0.939306</td>
#       <td>0.960260</td>
#       <td>0.831647</td>
#       <td>0.305154</td>
#       <td>0.187861</td>
#       <td>0.096026</td>
#       <td>0.831647</td>
#       <td>0.915462</td>
#       <td>0.939306</td>
#       <td>0.960260</td>
#       <td>0.898920</td>
#       <td>0.878947</td>
#       <td>0.880317</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.000400</td>
#       <td>0.066839</td>
#       <td>0.833092</td>
#       <td>0.919075</td>
#       <td>0.940029</td>
#       <td>0.960983</td>
#       <td>0.833092</td>
#       <td>0.306358</td>
#       <td>0.188006</td>
#       <td>0.096098</td>
#       <td>0.833092</td>
#       <td>0.919075</td>
#       <td>0.940029</td>
#       <td>0.960983</td>
#       <td>0.899747</td>
#       <td>0.879849</td>
#       <td>0.881111</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.000500</td>
#       <td>0.068103</td>
#       <td>0.834538</td>
#       <td>0.920520</td>
#       <td>0.
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# TrainOutput(global_step=2020, training_loss=0.04428339495074631, metrics={'train_runtime': 1988.1867, 'train_samples_per_second': 16.248, 'train_steps_per_second': 1.016, 'total_flos': 0.0, 'train_loss': 0.04428339495074631, 'epoch': 5.0})

# %%
# 7. Save the trained model
model.save_pretrained("/content/drive/MyDrive/myqas/models1/finetuned-indoSBERT-large-e5bs16")

# %%
# 8. Evaluate the trained model on the test set
corpus_test = {str(idx): answer for idx, answer in enumerate(dataset["test"]["answer"])}
queries_test = {str(idx): question for idx, question in enumerate(dataset["test"]["question"])}
relevant_docs_test = {str(idx): {str(idx)} for idx in range(len(dataset["test"]["question"]))}

test_evaluator = InformationRetrievalEvaluator(
    queries=queries_test,
    corpus=corpus_test,
    relevant_docs=relevant_docs_test,
    name="indoSBERT-large-test-e5b16",
)
test_evaluator(model)
# Out:
# {'indoSBERT-large-test-e5b16_cosine_accuracy@1': 0.8541516245487365,
#  'indoSBERT-large-test-e5b16_cosine_accuracy@3': 0.9299638989169675,
#  'indoSBERT-large-test-e5b16_cosine_accuracy@5': 0.9444043321299639,
#  'indoSBERT-large-test-e5b16_cosine_accuracy@10': 0.9574007220216606,
#  'indoSBERT-large-test-e5b16_cosine_precision@1': 0.8541516245487365,
#  'indoSBERT-large-test-e5b16_cosine_precision@3': 0.30998796630565584,
#  'indoSBERT-large-test-e5b16_cosine_precision@5': 0.18888086642599275,
#  'indoSBERT-large-test-e5b16_cosine_precision@10': 0.09574007220216606,
#  'indoSBERT-large-test-e5b16_cosine_recall@1': 0.8541516245487365,
#  'indoSBERT-large-test-e5b16_cosine_recall@3': 0.9299638989169675,
#  'indoSBERT-large-test-e5b16_cosine_recall@5': 0.9444043321299639,
#  'indoSBERT-large-test-e5b16_cosine_recall@10': 0.9574007220216606,
#  'indoSBERT-large-test-e5b16_cosine_ndcg@10': 0.9093403811689553,
#  'indoSBERT-large-test-e5b16_cosine_mrr@10': 0.8935192825626042,
#  'indoSBERT-large-test-e5b16_cosine_map@100': 0.8946077619613897}

# %% [markdown]
# # wandb close

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.022 MB of 0.022 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@1</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@10</td><td>▁▅▆▇▇▇▇▇▇█▇█████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@3</td><td>▁▅▇▇█▇█▇▇███████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@5</td><td>▁▅▇▇▇▇█▇▇███████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_map@100</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_mrr@10</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_ndcg@10</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@1</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@10</td><td>▁▅▆▇▇▇▇▇▇█▇█████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@3</td><td>▁▅▇▇█▇█▇▇███████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@5</td><td>▁▅▇▇▇▇█▇▇███████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@1</td><td>▁▅▇▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@10</td><td>▁▅▆▇▇▇▇▇▇█▇█████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@3</td><td>▁▅▇▇█▇█▇▇███████████████████████████████</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@5</td><td>▁▅▇▇▇▇█▇▇███████████████████████████████</td></tr><tr><td>eval/loss</td><td>█▃▂▂▁▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁▁▁▁▁▁▁▁▁▂▃█▁▃▄▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▇████████▇▆▁█▆▄▇████████▇█████▇██████▇██</td></tr><tr><td>eval/steps_per_second</td><td>▇████████▇▆▁█▆▄▇████████▇█████▇██████▇██</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train/grad_norm</td><td>▅▃█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▃▄▆████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▄▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@1</td><td>0.8396</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@10</td><td>0.95954</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@3</td><td>0.92269</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_accuracy@5</td><td>0.94003</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_map@100</td><td>0.88541</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_mrr@10</td><td>0.88406</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_ndcg@10</td><td>0.90262</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@1</td><td>0.8396</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@10</td><td>0.09595</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@3</td><td>0.30756</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_precision@5</td><td>0.18801</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@1</td><td>0.8396</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@10</td><td>0.95954</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@3</td><td>0.92269</td></tr><tr><td>eval/indoSBERT-large-eval_cosine_recall@5</td><td>0.94003</td></tr><tr><td>eval/loss</td><td>0.06753</td></tr><tr><td>eval/runtime</td><td>16.8502</td></tr><tr><td>eval/samples_per_second</td><td>82.136</td></tr><tr><td>eval/steps_per_second</td><td>5.163</td></tr><tr><td>total_flos</td><td>0</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_s ...
#  View run <strong style="color:#cdcd00">indoSBERT-large_e10bs16</strong> at: <a href='https://wandb.ai/1122am-university/sentence-transformers/runs/z13lh6c6' target="_blank">https://wandb.ai/1122am-university/sentence-transformers/runs/z13lh6c6</a><br/> View project at: <a href='https://wandb.ai/1122am-university/sentence-transformers' target="_blank">https://wandb.ai/1122am-university/sentence-transformers</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241217_033855-z13lh6c6/logs</code>

# %% [markdown]
# # QAS

# %%
def get_or_create_embeddings_qa(data, model, embeddings_path):
    corpus_questions = data['question'].tolist()
    corpus_answers = data['answer'].tolist()

    if not os.path.exists(embeddings_path):
        question_embeddings = model.encode(corpus_questions, show_progress_bar=True, convert_to_tensor=True)
        answer_embeddings = model.encode(corpus_answers, show_progress_bar=True, convert_to_tensor=True)

        with open(embeddings_path, 'wb') as fOut:
            pickle.dump(
                {
                    'questions': corpus_questions,
                    'answers': corpus_answers,
                    'question_embeddings': question_embeddings.cpu(),
                    'answer_embeddings': answer_embeddings.cpu()
                },
                fOut
            )
        print("Embeddings saved to:", embeddings_path)
    else:
        print("Embeddings file already exists. Loading embeddings from file...")
        with open(embeddings_path, 'rb') as fIn:
            cached_data = pickle.load(fIn)
            corpus_questions = cached_data['questions']
            corpus_answers = cached_data['answers']

            question_embeddings = cached_data['question_embeddings'].cpu()
            answer_embeddings = cached_data['answer_embeddings'].cpu()

    return corpus_questions, corpus_answers, question_embeddings, answer_embeddings

# %%
def semantic_search(queries, corpus, model, top_k=5):
    results_dict = {}

    if isinstance(queries, str):
        queries = [queries]

    query_embeddings = model.encode(queries, convert_to_tensor=True)
    hits_batch = util.semantic_search(query_embeddings, answer_embeddings, top_k=top_k)

    for query, hits in zip(queries, hits_batch):
        results = []
        for hit in hits:
            idx = hit['corpus_id']
            results.append({
                "score": hit['score'],
                "question": corpus.iloc[idx]['question'],
                "answer": corpus.iloc[idx]['answer']
            })
        results_dict[query] = results

    return results_dict

# %%
queries_path = '/content/drive/MyDrive/myData/dataset/pengujian_sistem.xlsx'

queries_pd = pd.read_excel(queries_path)
queries = queries_pd['kueri'].iloc[0:10].tolist()
queries
# Out:
# ['apa yang bisa kita pelajari dari iklim di masa lalu ',
#  'kapan dampak aktivitas manusia terhadap iklim mulai terlihat secara nyata pada tingkat lokal',
#  'apakah model iklim semakin berkembang',
#  'apa yang perlu diketahui manusia dalam adaptasi terhadap dampak bahaya  iklim',
#  'kenapa kota-kota yang berada di sekitar tepi laut yang paling beresiko terkena dampak perubahan iklim',
#  'apakah ada pengaruh terhadap rotasi planet apabila es di daerah kutub di bumi mencair ',
#  'apa kontribusi yang bisa saya lakukan dalam menghentikan perubahan iklim',
#  'bagaimana peluang dan tantangan dalam mitigasi berbeda di setiap wilayah?',
#  'cara mengetahui sehangat dan sedingin apa cuaca di jaman dulu',
#  'apa yang terjadi pada kehidupan anak-anak di masa depan apabila tidak ada aksi cepat dalam mengurangi gas emisi rumah kaca']

# %% [markdown]
# # qas indoSBERT model

# %%
model = SentenceTransformer('denaya/indoSBERT-large')
model
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.23k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/709k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 1024, 'out_features': 256, 'bias': True, 'activation_function': 'torch.nn.modules.activation.Tanh'})
# )

# %%
# embeddings_path_model = '/content/drive/MyDrive/myqas/models1/embeddings/embeddings_denaya-indoSBERT-large.pkl'
# corpus_questions, corpus_answers, question_embeddings, answer_embeddings = get_or_create_embeddings_qa_nopre(df1, model, embeddings_path_model)
# Out:
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Embeddings saved to: /content/drive/MyDrive/myqas/models1/embeddings/embeddings_denaya-indoSBERT-large.pkl

# %%
embeddings_path_model = '/content/drive/MyDrive/myqas/models1/embeddings/embeddings_denaya-indoSBERT-large.pkl'
corpus_questions, corpus_answers, question_embeddings, answer_embeddings = get_or_create_embeddings_qa(df1, model, embeddings_path_model)
# Out:
# Embeddings file already exists. Loading embeddings from file...

# %%
results = semantic_search(queries, df1, model, top_k=5)

for query, result_list in results.items():
    print(f"\nQuery: '{query}'")
    for res in result_list:
        print(f"Score: {res['score']:.3f}, Q: {res['question']}, A: {res['answer']}")
    print()
# Out:
# Query: 'apa yang bisa kita pelajari dari iklim di masa lalu '
# Score: 0.534, Q: Bagaimana kita mengetahui tingkat gas rumah kaca dan suhu di masa lalu?, A: Inti es merupakan sumber terbaik bagi para ilmuwan untuk mendapatkan data iklim historis. Alat lain untuk mempelajari atmosfer Bumi purba meliputi lingkaran pertumbuhan pada pohon, yang menyimpan catatan kasar suhu, kelembapan, dan tingkat kekeruhan setiap musim tanam yang telah berlangsung sekitar 2.000 tahun. Karang juga membentuk lingkaran pertumbuhan yang memberikan informasi tentang suhu dan nutrisi di lautan tropis. Proksi lainnya, seperti inti bentik, memperluas pengetahuan kita tentang iklim masa lalu hingga sekitar satu miliar tahun yang lalu.
# Score: 0.501, Q: Apa yang Dapat Diajarkan Iklim Masa Lalu kepada Kita tentang Masa Depan?, A: Di masa lalu, Bumi telah mengalami periode berkepanjangan dengan peningkatan konsentrasi gas rumah kaca yang menyebabkan suhu global dan permukaan laut naik. Mempelajari periode hangat di masa lalu ini memberi tahu kita tentang potensi konsekuensi jangka panjang dari peningkatan gas rumah kaca di atmosfer. Meningkatnya konsentrasi gas rumah kaca mendorong perubahan besar pada sistem Bumi, termasuk pemanasan global, kenaikan permukaan laut, peningkatan iklim dan cuaca ekstrem, pengasaman laut, dan pergeseran ekologi (FAQ 2.2 dan FAQ 7.1). Sebagian besar pengamatan instrumental iklim dimulai pada abad ke-20, ketika emisi gas rumah kaca dari aktivitas manusia menjadi pendorong utama perubahan iklim Bumi (FAQ 3.1). Ketika para ilmuwan berusaha menyempurnakan pemahaman kita tentang sistem iklim Bumi dan bagaimana sistem itu dapat berevolusi dalam beberapa dekade hingga abad mendatang, kondisi iklim masa lalu memberikan banyak wawasan. Data tentang kondisi masa lalu ini membantu membangun hubungan antara pendorong iklim alami dan sejarah perubahan suhu global, permukaan laut global, siklus karbon, sirkulasi laut, dan pola iklim regional, termasuk iklim ekstrem. Berdasarkan data tersebut, para ilmuwan menggunakan model sistem Bumi untuk mengidentifikasi rangkaian peristiwa yang mendasari transisi antara kondisi iklim masa lalu (FAQ 3.3). Hal ini
laut sebelumnya, pola iklim, dan pergeseran perubahan musim yang terkait dengan pembungaan pohon dan munculnya sumber makanan, yang dikembangkan selama ribuan generasi pengamatan terhadap negara tradisional mereka. Pengetahuan tentang adaptasi kontemporer yang dilokalkan juga dimiliki oleh banyak Masyarakat Adat Australia yang memiliki hubungan dengan tanah tradisional. Dengan persetujuan bebas dan berdasarkan informasi sebelumnya yang terjamin, hal ini menyediakan sarana untuk pengelolaan lahan yang dipandu oleh Masyarakat Adat, termasuk untuk pengelolaan kebakaran dan pengurangan karbon, studi fauna, produk tanaman obat, pemulihan spesies yang terancam, pengelolaan air, dan pengelolaan gulma. Tangata Whenua Māori di Selandia Baru didasarkan pada pengetahuan Mātauranga Māori, yang didasarkan pada hubungan manusia-alam dan integritas ekologis serta menggabungkan praktik yang digunakan untuk mendeteksi dan mengantisipasi perubahan yang terjadi di lingkungan. Jaringan dan konvensi sosial-budaya yang mempromosikan tindakan kolektif dan saling mendukung merupakan ciri utama banyak komunitas Māori dan pendekatan adat ini penting untuk menanggapi, dan memulihkan diri dari, kondisi lingkungan yang merugikan. Pendekatan antargenerasi untuk merencanakan masa depan juga merupakan bagian intrinsik dari organisasi sosial-budaya Māori dan diharapkan menjadi semakin penting, mengangkat diskusi politik tentang konsepsi rasionalitas, keragaman, dan hak-hak entitas non-manusia dalam kebijakan dan adaptasi perubahan iklim.
# Score: 0.500, Q: Seberapa banyak yang dapat kita katakan tentang seperti apa masyarakat di masa mendatang, untuk dapat merencanakan dampak perubahan iklim?, A: Karakteristik masyarakat dan ekonomi secara keseluruhan, seperti ukuran populasi, aktivitas ekonomi, dan penggunaan lahan, sangat dinamis. Dalam skala hanya 1 atau 2 dekade, dan terkadang dalam waktu yang lebih singkat dari itu, revolusi teknologi, gerakan politik, atau peristiwa tunggal dapat membentuk jalannya sejarah dengan cara yang tidak dapat diprediksi. Untuk memahami dampak potensial perubahan iklim bagi masyarakat dan ekosistem, para ilmuwan menggunakan skenario untuk mengeksplorasi implikasi dari berbagai kemungkinan masa depan. Skenario bukanlah prediksi tentang apa yang akan terjadi, tetapi dapat menjadi alat yang berguna untuk meneliti berbagai pertanyaan "bagaimana jika" tentang seperti apa dunia di masa depan. Skenario dapat digunakan untuk mempelajari emisi gas rumah kaca dan perubahan iklim di masa mendatang. Skenario juga dapat digunakan untuk mengeksplorasi cara dampak perubahan iklim bergantung pada perubahan dalam masyarakat, seperti pertumbuhan ekonomi atau populasi atau kemajuan dalam pengendalian penyakit. Skenario keputusan dan kebijakan yang mungkin dapat digunakan untuk mengeksplorasi ruang solusi untuk mengurangi emisi gas rumah kaca dan mempersiapkan diri menghadapi perubahan iklim. Analisis skenario menciptakan landasan untuk memahami risiko perubahan iklim bagi masyarakat, ekosistem, dan ekonomi di berbagai kemungkinan masa depan. Ini menyediakan alat penting untuk pengambilan keputusan cerdas ketika ketidakpastian dan konsekuensinya besar.
# Score: 0.488, Q: Bagaimana Australia dan Selandia Baru dapat beradaptasi dengan perubahan iklim?, A: Pemerintah, bisnis, komunitas, dan Masyarakat Adat telah berupaya membantu kita beradaptasi dengan perubahan iklim. Namun, diperlukan lebih banyak adaptasi mengingat risiko iklim yang terus berlanjut dan semakin meningkat. Ini termasuk undang-undang, rencana, panduan, dan pendanaan yang terkoordinasi yang memungkinkan masyarakat beradaptasi dan informasi, pendidikan, dan pelatihan yang dapat mendukungnya. Setiap orang memiliki peran untuk bekerja sama. Saat ini, kita terutama bereaksi terhadap peristiwa iklim seperti kebakaran hutan, gelombang panas, banjir, dan kekeringan dan umumnya membangun kembali di tempat yang sama. Namun, perubahan iklim membuat peristiwa ini lebih sering terjadi dan lebih intens, dan kenaikan permukaan laut yang sedang berlangsung serta perubahan ekosistem alam semakin meningkat. Koordinasi dan kolaborasi yang lebih baik antara lembaga pemerintah, komunitas, Aborigin dan Penduduk Kepulauan Selat Torres serta Masyarakat Adat Tangata Whenua, organisasi nirlaba, dan bisnis akan membantu mempersiapkan dampak iklim ini secara lebih proaktif, dikombinasikan dengan risiko iklim masa depan yang terintegrasi ke dalam keputusan dan perencanaan mereka. Ini akan mengurangi dampak yang kita alami sekarang dan risiko yang akan memengaruhi generasi mendatang. Beberapa risiko bagi sistem alam sudah mendekati ambang batas kritis dan adaptasi mungkin tidak dapat mencegah keruntuhan ekosistem. Risiko lainnya akan parah, tetapi kita dapat mengurangi dampaknya dengan bertindak sekarang, misalnya banjir pesisir akibat kenaikan muka air laut, kematian akibat panas, dan pengelolaan tekanan air. Banyak risiko yang berpotensi menyebar ke seluruh sektor sosial dan ekonomi dengan dampak sosial yang meluas. Dalam kasus seperti itu, perubahan sistem yang sangat signifikan akan diperlukan dalam cara kita hidup dan memerintah saat ini. Untuk memfasilitasi perubahan tersebut, kerangka tata kelola baru, informasi yang konsisten dan dapat diakses secara nasional, keterlibatan kolaboratif dan kemitraan dengan semua sektor, komunitas, dan Masyarakat Adat, serta sumber daya untuk mengatasi risiko diperlukan (Gambar FAQ11.4.1). Namun, kemampuan kita untuk beradaptasi dengan dampak perubahan iklim juga bergantung pada setiap wilayah di dunia yang memainkan perannya dalam mengurangi emisi gas rumah kaca. Jika mitigasi tidak efektif, pemanasan global akan berlangsung cepat dan biaya adaptasi akan meningkat, dengan kerugian dan kerusakan yang semakin parah. Gambar FAQ11.4.1 | Mengembangkan rencana adaptasi dalam ruang solusi yang menunjukkan titik kritis sistem, ambang batas dan batasan adaptasi, jalur yang tidak berkelanjutan, sistem kritis dan pendorong pembangunan yang tangguh terhadap iklim.
#
#
# Query: 'kapan dampak aktivitas manusia terhadap iklim mulai terlihat secara nyata pada tingkat lokal'
# Score: 0.699, Q: Mengapa sulit untuk memastikan peran perubahan iklim dalam dampak yang diamati pada manusia dan ekosistem?, A: Perubahan iklim merupakan salah satu dari banyak faktor yang memengaruhi masyarakat manusia dan ekosistem alam Bumi yang kompleks. Dalam beberapa kasus, dampak perubahan iklim memiliki pola unik dalam ruang atau waktu, yang menyediakan sidik jari untuk identifikasi. Dalam kasus lain, dampak potensial perubahan iklim benar-benar tercampur dengan dampak perubahan penggunaan lahan, pembangunan ekonomi, perubahan teknologi, atau proses lainnya. Tren dalam aktivitas manusia, kesehatan, dan masyarakat sering kali memiliki banyak penyebab yang terjadi secara bersamaan, sehingga sangat sulit untuk mengisolasi peran perubahan iklim. Banyak kerusakan terkait iklim diakibatkan oleh peristiwa cuaca ekstrem dan dapat dipengaruhi oleh perubahan frekuensi dan intensitas peristiwa ini akibat perubahan iklim. Peristiwa yang paling merusak jarang terjadi, dan tingkat kerusakannya bergantung pada konteksnya. Oleh karena itu, membangun kepercayaan statistik terhadap tren yang diamati, terutama dalam jangka waktu yang pendek, dapat menjadi tantangan. Meskipun demikian, banyak dampak perubahan iklim terhadap lingkungan fisik dan ekosistem telah diidentifikasi, dan semakin banyak dampak telah ditemukan dalam sistem manusia juga.
# Score: 0.695, Q: Apa perbedaan antara cuaca dan iklim?, A: "Cuaca" merujuk pada perubahan iklim yang lebih lokal yang kita lihat di sekitar kita, dalam skala waktu pendek dari menit ke jam ke hari ke minggu. Contohnya sudah umum – hujan, salju, awan, angin, badai petir, gelombang panas, dan banjir. "Iklim" merujuk pada rata-rata jangka panjang (bisa regional atau global), dan dapat dianggap sebagai cuaca yang dirata-ratakan selama beberapa musim, tahun, atau dekade.
# Score: 0.692, Q: Kapan Pengaruh Manusia terhadap Iklim Menjadi Jelas dalam Skala Lokal?, A: Pemanasan yang disebabkan oleh manusia sudah mulai terlihat jelas di daratan di beberapa wilayah tropis, terutama selama musim panas. Pemanasan akan terlihat jelas di garis lintang tengah—selama musim panas pada awalnya—dalam beberapa dekade mendatang. Tren ini diperkirakan akan muncul lebih lambat di sana, terutama selama musim dingin, karena variabilitas iklim alami meningkat seiring jarak dari ekuator dan selama musim dingin. Tren suhu yang sudah terdeteksi di banyak wilayah telah dikaitkan dengan pengaruh manusia. Variabel iklim yang sensitif terhadap suhu, seperti es laut Arktik, juga menunjukkan tren yang terdeteksi yang disebabkan oleh pengaruh manusia. Tren pemanasan yang terkait dengan perubahan global umumnya lebih terlihat dalam rata-rata suhu global daripada dalam rangkaian waktu suhu lokal ('lokal' di sini secara umum mengacu pada lokasi individual, atau rata-rata regional yang kecil). Ini karena sebagian besar variabilitas lokal iklim lokal dirata-ratakan dalam rata-rata global. Tren pemanasan multidekade yang terdeteksi di banyak wilayah dianggap berada di luar kisaran tren yang mungkin diharapkan dari variabilitas internal alami sistem iklim, tetapi tren tersebut hanya akan menjadi jelas ketika iklim rata-rata lokal muncul dari 'kebisingan' variabilitas tahun ke tahun. Seberapa cepat hal ini terjadi bergantung pada laju tren pemanasan dan jumlah variabilitas lokal. Tren pemanasan di masa mendatang tidak dapat diprediksi secara tepat, terutama pada skala lokal, sehingga perkiraan waktu munculnya tren pemanasan di masa mendatang tidak dapat dibuat dengan presisi. Di beberapa wilayah tropis, tren pemanasan telah muncul dari variabilitas lokal (FAQ 10.2, Gambar 1). Hal ini terjadi lebih cepat di daerah tropis karena variabilitas suhu di sana l
# Score: 0.564, Q: Bagaimana Perubahan Iklim Mempengaruhi Karakteristik Regional Bahaya Iklim?, A: Bahaya iklim adalah kondisi iklim yang berpotensi membahayakan sistem alam atau masyarakat. Contohnya termasuk gelombang panas, kekeringan, peristiwa hujan salju lebat, dan kenaikan permukaan laut. Ilmuwan iklim mencari pola dalam pendorong dampak iklim untuk mendeteksi tanda-tanda bahaya yang berubah yang dapat memengaruhi perencanaan pemangku kepentingan (FAQ 12.1). Penyedia layanan iklim bekerja dengan para pemangku kepentingan dan pakar dampak untuk mengidentifikasi respons sistem utama dan ambang batas toleransi (FAQ 12.2) dan kemudian memeriksa pengamatan historis dan proyeksi iklim masa depan untuk mengidentifikasi perubahan terkait dengan karakteristik profil bahaya regional. Perubahan iklim dapat mengubah setidaknya lima karakteristik berbeda dari profil bahaya suatu wilayah (FAQ 12.3, Gambar 1): Besaran atau intensitas adalah nilai mentah dari bahaya iklim, seperti peningkatan suhu tahunan maksimum atau ketinggian banjir yang diakibatkan oleh badai pantai dengan perubahan 1% yang terjadi setiap tahun. Frekuensi adalah berapa kali bahaya iklim mencapai atau melampaui ambang batas selama periode tertentu. Misalnya, peningkatan jumlah kejadian hujan salju lebat, tornado, atau banjir yang dialami dalam setahun atau dalam satu dekade. Durasi adalah lamanya waktu di mana kondisi berbahaya bertahan melampaui ambang batas, seperti peningkatan jumlah hari berturut-turut di mana suhu udara maksimum melebihi 35°C, jumlah bulan berturut-turut kondisi kekeringan, atau jumlah hari di mana siklon tropis memengaruhi suatu lokasi. Waktumenangkap terjadinya kejadian berbahaya dalam kaitannya dengan perjalanan satu hari, musim, tahun, atau periode lain di mana elemen sektoral berevolusi atau saling bergantung (seperti waktu dalam setahun ketika hewan yang bermigrasi berharap menemukan pasokan makanan musiman). Contohnya termasuk pergeseran ke hari yang lebih awal dalam setahun ketika embun beku musim semi terakhir terjadi atau penundaan tanggal kedatangan yang khas untuk hujan musiman pertama, lamanya periode musim dingin ketika tanah biasanya tertutup salju, atau pengurangan waktu yang biasanya dibutuhkan agar kelembapan tanah berubah dari kondisi normal ke kekeringan. Luas spasial adalah wilayah tempat kondisi berbahaya diperkirakan terjadi, seperti wilayah yang saat ini terancam oleh siklon tropis, wilayah geografis tempat hari terdingin dalam setahun membatasi hama atau patogen tertentu, medan tempat permafrost berada, wilayah yang akan banjir setelah badai biasa, zona tempat kondisi iklim mendukung kerja di luar ruangan, atau ukuran gelombang panas laut. Perubahan profil bahaya sering kali saling terkait atau berasal dari perubahan fisik terkait pada sistem iklim. Misalnya, perubahan dalam frekuensi dan besarnya kejadian ekstrem sering kali berhubungan langsung satu sama lain sebagai akibat dari dinamika atmosfer dan proses kimia. Dalam banyak kasus, satu aspek perubahan baha
yang sebelumnya tidak cocok. Negara-negara berpenghasilan rendah cenderung lebih rentan terhadap risiko iklim dan beberapa langkah adaptasi – seperti meningkatkan akses ke fasilitas pendidikan dan kesehatan – akan tumpang tindih dengan program pembangunan yang ada. Namun, adaptasi melampaui sekadar pembangunan untuk mencakup langkah-langkah untuk mengatasi risiko tambahan yang secara khusus disebabkan oleh perubahan iklim, seperti meningkatkan ketinggian pertahanan laut. Masih belum jelas seberapa mahal biaya yang dibutuhkan untuk langkah-langkah ini atau siapa yang akan membayarnya, tetapi Bank Dunia memperkirakan biaya adaptasi bisa jadi sama dengan biaya yang dikeluarkan dunia saat ini untuk bantuan pembangunan.
# Score: 0.653, Q: Apa saja pilihan adaptasi saat ini dan yang muncul di seluruh Asia?, A: Mencerminkan heterogenitas di seluruh Asia, berbagai negara dan masyarakat melakukan berbagai strategi reaktif dan proaktif untuk mengelola risiko di berbagai sektor. Beberapa tindakan adaptasi ini menunjukkan harapan, mengurangi kerentanan dan meningkatkan kesejahteraan masyarakat. Namun, tantangan tetap ada seputar peningkatan tindakan adaptasi dengan cara yang efektif dan inklusif sekaligus memenuhi tujuan pembangunan nasional. Asia menunjukkan variasi yang luar biasa dalam hal ekosistem, pembangunan ekonomi, budaya, dan paparan risiko iklim. Mencerminkan variasi ini, rumah tangga, masyarakat, dan pemerintah memiliki berbagai strategi penanggulangan dan adaptasi untuk menghadapi perubahan kondisi iklim, dengan manfaat bersama untuk berbagai masalah non-iklim seperti kemiskinan, konflik, dan dinamika mata pencaharian. Saat ini, negara-negara Asia memiliki banyak bukti tentang pengelolaan risiko, yang diambil dari sejarah panjang dalam menghadapi perubahan. Misalnya, untuk menghadapi curah hujan yang tidak menentu dan pergeseran musim hujan, petani melakukan perubahan bertahap seperti mengubah apa dan kapan mereka menanam atau menyesuaikan praktik irigasi mereka. Masyarakat yang tinggal di pemukiman pesisir menggunakan sistem peringatan dini untuk bersiap menghadapi siklon atau meninggikan rumah mereka untuk meminimalkan dampak banjir. Jenis strategi ini, yang terlihat di seluruh subwilayah Asia, berdasarkan konteks sosial dan ekologi setempat, disebut adaptasi otonom yang terjadi secara bertahap dan membantu masyarakat mengelola dampak saat ini. Saat ini dan di masa mendatang, Asia diidentifikasi sebagai salah satu wilayah yang paling rentan terhadap perubahan iklim, terutama pada panas ekstrem, banjir, kenaikan permukaan laut, dan curah hujan yang tidak menentu. Semua risiko iklim ini, jika ditumpangkan pada defisit pembangunan yang ada, menunjukkan kepada kita bahwa adaptasi bertahap tidak akan cukup; perubahan transformasional diperlukan. Menyadari hal ini, di tingkat subnasional dan nasional, pemerintah dan pelaku nonpemerintah juga memprioritaskan strategi adaptasi terencana yang mencakup intervensi seperti 'pertanian cerdas iklim' seperti yang terlihat di negara-negara Asia Selatan dan Tenggara, atau mengubah undang-undang ketenagakerjaan untuk mengurangi paparan panas seperti yang terlihat di Asia Barat. Ini sering kali merupakan prioritas sektoral yang ditetapkan pemerintah melalui kebijakan dan proyek nasional atau subnasional, dengan mem
ian, dan pemberantasan pembakaran minyak tanah untuk penerangan. Namun, ada juga tindakan yang saling menguntungkan. Misalnya, pembakaran kayu didefinisikan sebagai netral karbon karena pohon mengumpulkan jumlah karbon dioksida yang sama sepanjang hidupnya seperti yang dilepaskan ketika kayu dari pohon itu dibakar. Namun, pembakaran kayu juga dapat mengakibatkan emisi polutan udara yang signifikan, termasuk karbon monoksida, nitrogen oksida, senyawa organik yang mudah menguap, dan partikel materi, yang secara lokal atau regional memengaruhi iklim, kesehatan manusia, dan ekosistem (FAQ 6.2, Gambar 1). Alternatifnya, mengurangi jumlah aerosol sulfat yang dihasilkan oleh pembangkit listrik dan industri, dan dari transportasi laut, meningkatkan kualitas udara tetapi menghasilkan pengaruh pemanasan pada iklim, karena aerosol sulfat tersebut berkontribusi untuk mendinginkan atmosfer dengan menghalangi sinar matahari yang masuk. Kualitas udara dan perubahan iklim merupakan dua sisi mata uang yang sama, dan menangani kedua masala ...
# Score: 0.615, Q: Apakah sudah terlambat untuk mencegah perubahan iklim?, A: Manusia telah menyebabkan perubahan iklim yang besar, dan kita telah memulai lebih banyak perubahan lagi. Bahkan jika kita berhenti mengeluarkan gas rumah kaca hari ini, pemanasan global akan terus terjadi setidaknya selama beberapa dekade lagi, bahkan berabad-abad.
# Score: 0.607, Q: Berapa banyak waktu yang kita miliki untuk menghentikan perubahan iklim?, A: Sebenarnya tidak ada batas waktu yang pasti antara aksi iklim dan tidak adanya aksi. Beberapa penelitian dan artikel menunjukkan bahwa kecuali kita membuat kemajuan signifikan menuju dekarbonisasi (mengurangi karbon dari atmosfer dan mengganti bahan bakar fosil dalam perekonomian kita) pada tahun 2030, kita mungkin akan menghadapi dampak iklim yang dahsyat yang akan membanjiri masyarakat kita dan menimbulkan ancaman eksistensial bagi ekosistem tertentu. Tidak ada garis demarkasi pasti yang dapat kita lindungi, sebaliknya ini adalah masalah meminimalkan dampak perubahan iklim. Setiap hari yang berlalu, kita melepaskan karbon ke atmosfer dan meningkatkan risiko planet kita. Sebagian besar ilmuwan setuju bahwa kita perlu mulai mengurangi emisi karbon SEKARANG JUGA untuk memberikan planet kita dan populasi kita masa depan yang paling tidak terdampak.

# %%
# Jawaban benar untuk setiap query berdasarkan kolom 'kueri' dan 'question' pada DataFrame queries_pd
correct_answers = {row['kueri']: row['question'] for _, row in queries_pd.iloc[0:11].iterrows()}

rows = []
for query, result_list in results.items():
    correct_answer = correct_answers[query]
    rank = 0
    questions = []

    # Menyimpan 5 pertanyaan per query
    for i, res in enumerate(result_list[:5]):
        questions.append(f"{i + 1}. {res['question']}")
        if res["question"] == correct_answer:
            rank = i + 1

    reciprocal_rank = 1 / rank if rank > 0 else 0

    question_text = "\n".join(questions)

    rows.append({
        "Query": query,
        "Questions": question_text,
        "Rank": rank,
        "Reciprocal Rank": reciprocal_rank,
    })

mrr_df = pd.DataFrame(rows)

# Menghitung MRR secara keseluruhan
mrr_overall = mrr_df["Reciprocal Rank"].mean()

print(mrr_df)
print(f"\nMean Reciprocal Rank (MRR): {mrr_overall:.3f}")
# Out:
#                                                Query  \
# 0  apa yang bisa kita pelajari dari iklim di masa...
# 1  kapan dampak aktivitas manusia terhadap iklim ...
# 2              apakah model iklim semakin berkembang
# 3  apa yang perlu diketahui manusia dalam adaptas...
# 4  kenapa kota-kota yang berada di sekitar tepi l...
# 5  apakah ada pengaruh terhadap rotasi planet apa...
# 6  apa kontribusi yang bisa saya lakukan dalam me...
# 7  bagaimana peluang dan tantangan dalam mitigasi...
# 8  cara mengetahui sehangat dan sedingin apa cuac...
# 9  apa yang terjadi pada kehidupan anak-anak di m...
#
#                                            Questions  Rank  Reciprocal Rank
# 0  1. Bagaimana kita mengetahui tingkat gas rumah...     2         0.500000
# 1  1. Mengapa sulit untuk memastikan peran peruba...     3         0.333333
# 2  1. Apakah sudah terlambat untuk mencegah perub...     0         0.000000
# 3  1. Apa itu adaptasi perubahan iklim?\n2. Apa s...     4         0.250000
# 4  1. Mengapa kota-kota pesisir dan pemukiman di ...     1         1.000000
# 5  1. Apa perbedaan antara perubahan iklim dan pe...     4         0.250000
# 6  1. Apa yang dilakukan TNC terhadap perubahan i...     0         0.000000
# 7  1. Komunitas mana yang paling rentan terhadap ...     0         0.000000
# 8  1. Apakah Bumi terus menghangat sejak 1998?\n2...     0         0.000000
# 9  1. Bagaimana perubahan iklim akan mempengaruhi...     1         1.000000
#
# Mean Reciprocal Rank (MRR): 0.333

# %%
mrr_df.to_excel('/content/drive/MyDrive/myData/dataset/hasilq-a1.xlsx')

# %% [markdown]
# # qas finetuned indoSBERT model

# %%
model2= SentenceTransformer('/content/drive/MyDrive/myqas/models1/finetuned-indoSBERT-large-e5bs16.h5')
model2
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 1024, 'out_features': 256, 'bias': True, 'activation_function': 'torch.nn.modules.activation.Tanh'})
# )

# %%
# embeddings_path_model2 = '/content/drive/MyDrive/myqas/models1/embeddings/embeddings_indoSBERT-e5b16.pkl'
# corpus_questions, corpus_answers, question_embeddings, answer_embeddings = get_or_create_embeddings_qa_nopre(df1, model2, embeddings_path_model2)
# Out:
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Embeddings saved to: /content/drive/MyDrive/myqas/models1/embeddings/embeddings_indoSBERT-e5b16.pkl

# %%
embeddings_path_model2 = '/content/drive/MyDrive/myqas/models1/embeddings/embeddings_indoSBERT-e5b16.pkl'
corpus_questions, corpus_answers, question_embeddings, answer_embeddings = get_or_create_embeddings_qa(df1, model2, embeddings_path_model2)
# Out:
# Embeddings file already exists. Loading embeddings from file...

# %%
results = semantic_search(queries, df1, model2, top_k=5)

for query, result_list in results.items():
    print(f"\nQuery: '{query}'")
    for res in result_list:
        print(f"Score: {res['score']:.3f}, Q: {res['question']}, A: {res['answer']}")
    print()
# Out:
# Query: 'apa yang bisa kita pelajari dari iklim di masa lalu '
# Score: 0.501, Q: Apa yang Dapat Diajarkan Iklim Masa Lalu kepada Kita tentang Masa Depan?, A: Di masa lalu, Bumi telah mengalami periode berkepanjangan dengan peningkatan konsentrasi gas rumah kaca yang menyebabkan suhu global dan permukaan laut naik. Mempelajari periode hangat di masa lalu ini memberi tahu kita tentang potensi konsekuensi jangka panjang dari peningkatan gas rumah kaca di atmosfer. Meningkatnya konsentrasi gas rumah kaca mendorong perubahan besar pada sistem Bumi, termasuk pemanasan global, kenaikan permukaan laut, peningkatan iklim dan cuaca ekstrem, pengasaman laut, dan pergeseran ekologi (FAQ 2.2 dan FAQ 7.1). Sebagian besar pengamatan instrumental iklim dimulai pada abad ke-20, ketika emisi gas rumah kaca dari aktivitas manusia menjadi pendorong utama perubahan iklim Bumi (FAQ 3.1). Ketika para ilmuwan berusaha menyempurnakan pemahaman kita tentang sistem iklim Bumi dan bagaimana sistem itu dapat berevolusi dalam beberapa dekade hingga abad mendatang, kondisi iklim masa lalu memberikan banyak wawasan. Data tentang kondisi masa lalu ini membantu membangun hubungan antara pendorong iklim alami dan sejarah perubahan suhu global, permukaan laut global, siklus karbon, sirkulasi laut, dan pola iklim regional, termasuk iklim ekstrem. Berdasarkan data tersebut, para ilmuwan menggunakan model sistem Bumi untuk mengidentifikasi rangkaian peristiwa yang mendasari transisi antara kondisi iklim masa lalu (FAQ 3.3). Hal ini penting karena selama perubahan iklim saat ini, seperti halnya perubahan iklim di masa lalu, beberapa aspek sistem Bumi (misalnya, suhu permukaan) merespons perubahan gas rumah kaca dalam skala waktu puluhan hingga ratusan tahun, sementara yang lain (misalnya, permukaan laut dan siklus karbon) merespons selama berabad-abad hingga ribuan tahun (FAQ 5.3). Dengan cara ini, kondisi iklim masa lalu berfungsi sebagai tolok ukur penting untuk simulasi model iklim, yang meningkatkan pemahaman kita tentang urutan, laju, dan besarnya perubahan iklim di masa mendatang selama beberapa dekade hingga ribuan tahun mendatang. Menganalisis periode hangat sebelumnya yang disebabkan oleh faktor-faktor alam dapat membantu kita memahami bagaimana aspek-aspek utama sistem iklim berevolusi sebagai respons terhadap pemanasan. Misalnya, satu kondisi iklim hangat sebelumnya terjadi sekitar 125.000 tahun yang lalu, selama periode Interglasial Terakhir, ketika sedikit variasi dalam orbit Bumi memicu serangkaian perubahan yang menyebabkan pemanasan global sekitar 1°C–2°C dan kenaikan permukaan laut sekitar 2–8 m relatif terhadap tahun 1850–1900, meskipun konsentrasi karbon dioksida atmosfer mirip dengan nilai tahun 1850–1900 (FAQ 1.3, Gambar 1). Studi pemodelan menyoroti bahwa peningkatan pemanasan musim panas di lintang yang lebih tinggi di Belahan Bumi Utara selama waktu ini menyebabkan pencairan salju dan es yang meluas, mengurangi reflektivitas planet dan meningkatkan penyerapan energi matahari oleh permukaan Bumi. Hal ini menimbulkan pemanasan skala global, yang pada gilirannya menyebabkan hilangnya es lebih lanjut dan kenaikan permukaan laut. Siklus umpan balik positif yang saling memperkuat ini merupakan fitur yang meluas dari sistem iklim Bumi, dengan implikasi yang jelas untuk perubahan iklim di masa mendatang di bawah emisi gas rumah kaca yang berkelan
# Score: 0.426, Q: Jadi, apa itu perubahan iklim?, A: Perubahan iklim (atau pemanasan global) adalah proses pemanasan planet kita. Para ilmuwan memperkirakan bahwa sejak Revolusi Industri, aktivitas manusia telah menyebabkan Bumi memanas sekitar 1°C. Meskipun kedengarannya tidak terlalu berarti, hal itu berarti hal yang besar bagi manusia dan satwa liar di seluruh dunia. Sayangnya, peningkatan suhu tidak hanya berarti kita akan mendapatkan cuaca yang lebih baik – jika saja! Perubahan iklim sebenarnya akan membuat cuaca kita lebih ekstrem dan tidak dapat diprediksi. Saat suhu meningkat, beberapa area akan menjadi lebih basah dan banyak hewan (dan manusia!) mungkin tidak dapat beradaptasi dengan perubahan iklim.
# Score: 0.409, Q: Apakah sudah terlambat untuk mencegah perubahan iklim?, A: Manusia telah menyebabkan perubahan iklim yang besar, dan kita telah memulai lebih banyak perubahan lagi. Bahkan jika kita berhenti mengeluarkan gas rumah kaca hari ini, pemanasan global akan terus terjadi setidaknya selama beberapa dekade lagi, bahkan berabad-abad.
#
#
# Query: 'kapan dampak aktivitas manusia terhadap iklim mulai terlihat secara nyata pada tingkat lokal'
# Score: 0.637, Q: Kapan Pengaruh Manusia terhadap Iklim Menjadi Jelas dalam Skala Lokal?, A: Pemanasan yang disebabkan oleh manusia sudah mulai terlihat jelas di daratan di beberapa wilayah tropis, terutama selama musim panas. Pemanasan akan terlihat jelas di garis lintang tengah—selama musim panas pada awalnya—dalam beberapa dekade mendatang. Tren ini diperkirakan akan muncul lebih lambat di sana, terutama selama musim dingin, karena variabilitas iklim alami meningkat seiring jarak dari ekuator dan selama musim dingin. Tren suhu yang sudah terdeteksi di banyak wilayah telah dikaitkan dengan pengaruh manusia. Variabel iklim yang sensitif terhadap suhu, seperti es laut Arktik, juga menunjukkan tren yang terdeteksi yang disebabkan oleh pengaruh manusia. Tren pemanasan yang terkait dengan perubahan global umumnya lebih terlihat dalam rata-rata suhu global daripada dalam rangkaian waktu suhu lokal ('lokal' di sini secara umum mengacu pada lokasi individual, atau rata-rata regional yang kecil). Ini karena sebagian besar variabilitas lokal iklim lokal dirata-ratakan dalam rata-rata global. Tren pemanasan multidekade yang terdeteksi di banyak wilayah dianggap berada di luar kisaran tren yang mungkin diharapkan dari variabilitas internal alami sistem iklim, tetapi tren tersebut hanya akan menjadi jelas ketika iklim rata-rata lokal muncul dari 'kebisingan' variabilitas tahun ke tahun. Seberapa cepat hal ini terjadi bergantung pada laju tren pemanasan dan jumlah variabilitas lokal. Tren pemanasan di masa mendatang tidak dapat diprediksi secara tepat, terutama pada skala lokal, sehingga perkiraan waktu munculnya tren pemanasan di masa mendatang tidak dapat dibuat dengan presisi. Di beberapa wilayah tropis, tren pemanasan telah muncul dari variabilitas lokal (FAQ 10.2, Gambar 1). Hal ini terjadi lebih cepat di daerah tropis karena variabilitas suhu di sana lebih sedikit daripada di bagian lain dunia. Pemanasan yang diproyeksikan mungkin tidak muncul di garis lintang tengah hingga pertengahan abad ke-21—meskipun tren pemanasan di sana lebih besar—karena variabilitas suhu lokal jauh lebih besar di sana daripada di daerah tropis. Secara musiman, variabilitas suhu lokal cenderung lebih kecil di musim panas daripada di musim dingin. Oleh karena itu, pemanasan cenderung muncul pertama kali di bagian tahun yang hangat, bahkan di wilayah yang tren pemanasannya lebih besar di musim dingin, seperti di Eurasia tengah dalam FAQ 10.2, Gambar 1. Variabel selain suhu permukaan daratan, termasuk beberapa wilayah samudra, juga menunjukkan laju perubahan jangka panjang yang berbeda dari variabilitas alami. Misalnya, luas es laut Arktik menurun sangat cepat, dan sudah menunjukkan pengaruh manusia. Di sisi lain, tren presipitasi lokal sangat sulit dideteksi karena di sebagian besar lokasi variabilitas presipitasi cukup besar. Probabilitas suhu musim panas yang hangat dan memecahkan rekor telah meningkat di sebagian besar Belahan Bumi Utara. Suhu tinggi yang saat ini dianggap ekstrem diproyeksikan akan mendekati norma selama beberapa dekade mendatang. Probabilitas kejadian ekstrem lainnya, termasuk beberapa periode dingin, telah berkurang. Dalam iklim saat ini, masing-masing kejadian cuaca ekstrem tidak dapat secara jelas dikaitkan dengan perubahan iklim, karena kejadian tersebut dapat terjadi dalam iklim yang tidak berubah. Namun, probabilitas terjadinya kejadian tersebut dapat berubah secara signifikan di lokasi tertentu. Peningkatan gas rumah kaca yang disebabkan oleh manusia diperkirakan telah memberikan kontribusi yang cukup besar terhadap kemungkinan terjadinya beberapa gelombang panas. Demikian pula, studi model iklim menunjukkan bahwa peningkatan gas rumah kaca telah memberikan kontribusi terhadap intensifikasi yang diamati dari peristiwa curah hujan lebat yang ditemukan di beberapa bagian Belahan Bumi Utara. Namun, kemungkinan banyak peristiwa cuaca ekstrem lainnya mungkin tidak berubah secara substansial. Oleh karena itu, tidaklah tepat untuk mengang ...
# Score: 0.622, Q: Apakah sudah terlambat untuk mencegah perubahan iklim?, A: Manusia telah menyebabkan perubahan iklim yang besar, dan kita telah memulai lebih banyak perubahan lagi. Bahkan jika kita berhenti mengeluarkan gas rumah kaca hari ini, pemanasan global akan terus terjadi setidaknya selama beberapa dekade lagi, bahkan berabad-abad.
# Score: 0.558, Q: Kapan kita menemukan perubahan iklim buatan manusia?, A: Pada awal abad ke-20, anggapan yang berlaku adalah bahwa manusia dapat mengubah iklim secara lokal (misalnya, dengan menebang hutan dan membajak ladang yang belum digarap) tetapi tidak secara global. Tentu saja, zaman es dan perubahan iklim yang menyakitkan lainnya di masa lalu menjadi topik penelitian. Namun, hanya sedikit yang menganggapnya sebagai ancaman langsung, dan hampir tidak ada yang mengira manusia dapat memicu perubahan iklim di seluruh dunia. Beberapa pemikir perintis – seperti ahli kimia Swedia Svante Arrhenius pada tahun 1890-an – telah melihat potensi dampak global dari penggunaan bahan bakar fosil, tetapi pandangan mereka biasanya ditolak oleh rekan-r
di masa mendatang akan terus menunjukkan sinyal terbesar di lintang utara yang tinggi, tetapi dengan pemanasan paling nyata di wilayah tropis. Wilayah tropis juga akan memperoleh manfaat paling besar dari mitigasi perubahan iklim dalam konteks ini, karena membatasi pemanasan global juga akan membatasi sejauh mana perubahan iklim relatif terhadap pengalaman masa lalu. Perubahan variabel iklim lainnya juga menjadi tampak pada skala spasial yang lebih kecil. Misalnya, perubahan curah hujan rata-rata mulai terlihat jelas di beberapa wilayah, tetapi tidak di wilayah lain, terutama karena variasi curah hujan alami dari tahun ke tahun cenderung besar dibandingkan dengan besarnya tren jangka panjang. Namun, curah hujan ekstrem menjadi lebih intens di banyak wilayah, yang berpotensi meningkatkan dampak banjir di daratan (FAQ 8.2). Permukaan laut juga jelas meningkat di banyak garis pantai, meningkatkan dampak banjir akibat gelombang badai pesisir, bahkan tanpa peningkatan jumlah badai yang mencapai daratan. Penurunan jumlah es laut Arktik terlihat jelas, baik di area yang tertutup maupun ketebalannya, dengan implikasi bagi ekosistem kutub. Ketika mempertimbangkan dampak terkait iklim, yang terpenting bukanlah ukuran perubahannya. Sebaliknya, yang terpenting adalah laju perubahannya atau bisa juga ukuran perubahannya relatif terhadap variasi alami iklim yang menjadi tempat adaptasi ekosistem dan masyarakat. Ketika iklim semakin menjauh dari pengalaman masa lalu dan memasuki kondisi yang belum pernah terjadi sebelumnya, dampaknya dapat menjadi lebih besar, seiring dengan tantangan untuk beradaptasi dengannya. Bagaimana dan kapan tren jangka panjang menjadi dapat dibedakan dari variasi alami jangka pendek bergantung pada aspek iklim yang dipertimbangkan (misalnya, suhu, curah hujan, es laut atau permukaan laut), wilayah yang dipertimbangkan, laju perubahan, dan besarnya serta waktu terjadinya variasi alami. Saat menilai dampak lokal dari perubahan iklim, baik ukuran perubahan maupun amplitudo variasi alami menjadi penting.
#
#
# Query: 'apakah model iklim semakin berkembang'
# Score: 0.623, Q: Mengapa Begitu Banyak Model dan Skenario yang Digunakan untuk Memproyeksikan Perubahan Iklim?, A: Iklim masa depan sebagian ditentukan oleh besarnya emisi gas rumah kaca, aerosol, dan gaya-gaya alami dan buatan manusia lainnya di masa depan. Gaya-gaya ini bersifat eksternal terhadap sistem iklim, tetapi mengubah perilakunya. Iklim masa depan dibentuk oleh respons Bumi terhadap gaya-gaya tersebut, bersama dengan variabilitas internal yang melekat dalam sistem iklim. Berbagai asumsi tentang besarnya dan laju emisi masa depan membantu para ilmuwan mengembangkan berbagai skenario emisi, yang menjadi dasar proyeksi model iklim. Sementara itu, berbagai model iklim memberikan representasi alternatif dari respons Bumi terhadap gaya-gaya tersebut, dan variabilitas iklim alami. Secara bersama-sama, kumpulan model, yang mensimulasikan respons terhadap berbagai skenario yang berbeda, memetakan berbagai kemungkinan masa depan, dan membantu kita memahami ketidakpastiannya. Memprediksi perkembangan sosial ekonomi bisa dibilang bahkan lebih sulit daripada memprediksi evolusi sistem fisik. Ini memerlukan prediksi perilaku manusia, pilihan kebijakan, kemajuan teknologi, persaingan dan kerja sama internasional. Pendekatan yang umum adalah menggunakan skenario perkembangan sosial ekonomi masa depan yang masuk akal, yang darinya emisi gas rumah kaca dan agen pemaksaan lainnya di masa depan diturunkan. Secara umum, tidak mungkin untuk menetapkan kemungkinan pada skenario pemaksaan individual. Sebaliknya, serangkaian alternatif digunakan untuk menjangkau berbagai kemungkinan. Hasil dari berbagai skenario pemaksaan memberi para pembuat kebijakan alternatif dan berbagai kemungkinan masa depan untuk dipertimbangkan. Fluktuasi internal dalam iklim secara spontan dihasilkan oleh interaksi antara komponen-komponen seperti atmosfer dan lautan. Dalam kasus perubahan iklim jangka pendek, hal itu dapat melampaui efek gangguan eksternal, seperti peningkatan gas rumah kaca (lihat Bab 11). Namun, dalam jangka panjang, efek pemaksaan eksternal diharapkan akan mendominasi. Simulasi model iklim memproyeksikan bahwa, setelah beberapa dekade, berbagai skenario gas rumah kaca antropogenik di masa depan dan agen pemaksaan lainnya—dan respons sistem iklim terhadapnya—akan secara berbeda memengaruhi perubahan suhu global rata-rata (FAQ 12.1, Gambar 1, panel kiri). Oleh karena itu, mengevaluasi konsekuensi dari berbagai skenario dan respons tersebut menjadi sangat penting, terutama ketika keputusan kebijakan dipertimbangkan. Model iklim dibangun berdasarkan prinsip-prinsip fisika yang mengatur sistem iklim kita, dan pemahaman empiris, serta mewakili proses-proses yang kompleks dan saling berinteraksi yang diperlukan untuk mensimulasikan iklim dan perubahan iklim, baik di masa lalu maupun di masa depan. Analogi dari pengamatan masa lalu, atau ekstrapolasi dari tren terkini, bukanlah strategi yang memadai untuk menghasilkan proyeksi, karena masa depan tidak akan selalu menjadi kelanjutan sederhana dari apa yang telah kita lihat sejauh ini. Meskipun dimungkinkan untuk menuliskan persamaan gerak fluida yang menentukan perilaku atmosfer dan lautan, mustahil untuk menyelesaikannya tanpa menggunakan algoritma numerik melalui simulasi model komputer, sama seperti bagaimana rekayasa pesawat terbang bergantung pada simulasi numerik dari jenis persamaan yang serupa. Selain itu, banyak proses fisik, biologis, dan kimia skala kecil, seperti proses awan, tidak dapat dijelaskan oleh persamaan tersebut, baik karena kita tidak memiliki kemampuan komputasi untuk menggambarkan sistem pada resolusi yang cukup baik untuk secara langsung mensimulasikan proses-proses ini atau karena kita masih memiliki pemahaman ilmiah parsial tentang mekanisme yang mendorong proses-proses ini. Hal itu perlu didekati dengan apa yang disebut parameterisasi dalam model iklim, yang melaluinya hubungan matematis antara kuantitas yang disimulasikan secara langsung dan kuantitas yang didekati ditetap ...
# Score: 0.621, Q: Apakah Model Iklim Membaik?, A: Model iklim merupakan perangkat penting untuk memahami perubahan iklim di masa lalu, sekarang, dan masa depan. Model iklim merupakan program komputer canggih yang didasarkan pada hukum dasar fisika atmosfer, lautan, es, dan daratan. Model iklim melakukan perhitungannya pada kisi tiga dimensi yang terbuat dari batu bata kecil atau 'sel kisi' dengan lebar sekitar 100 km. Proses yang terjadi pada skala yang lebih kecil daripada sel kisi model (seperti transformasi kelembapan awan menjadi hujan) diperlakukan dengan cara yang disederhanakan. Penyederhanaan ini dilakukan secara berbeda dalam model yang berbeda. Beberapa model mencakup lebih banyak proses dan kompleksitas daripada yang lain; beberapa menggambarkan proses dengan lebih rinci (sel kisi yang lebih kecil) daripada yang lain. Oleh karena itu, iklim dan perubahan iklim yang disimulasikan bervariasi antarmodel. Pemodelan iklim dimulai pada tahun 1950-an dan, selama bertahun-tahun, model telah menjadi semakin canggih seiring dengan kemajuan daya komputasi, pengamatan, dan pemahaman kita tentang sistem iklim. Model yang digunakan dalam Laporan Penilaian Pertama IPCC yang diterbitkan pada tahun 1990 mereproduksi banyak aspek iklim dengan benar (FAQ 1.1). Perkembangan iklim yang sebenarnya sejak saat itu telah mengonfirmasi proyeksi awal ini, ketika memperhitungkan perbedaan antara skenario simulasi dan emisi aktual. Model terus membaik dan menjadi semakin baik dalam simulasi berbagai macam proses penting yang memengaruhi iklim. Misalnya, banyak model sekarang mensimulasikan interaksi kompleks antara berbagai aspek sistem Bumi, seperti penyerapan karbon dioksida oleh tumbuhan di daratan dan lautan, dan interaksi antara awan dan polutan udara. Sementara beberapa model menjadi lebih komprehensif, yang lain berusaha untuk merepresentasikan proses pada resolusi yang lebih tinggi, misalnya untuk merepresentasikan pusaran dan pusaran arus yang bertanggung jawab atas sebagian besar perpindahan panas di lautan dengan lebih baik. Para ilmuwan mengevaluasi kinerja model iklim dengan membandingkan simulasi model iklim historis dengan pengamatan. Evaluasi ini mencakup perbandingan rata-rata skala besar serta variasi regional dan musiman yang lebih rinci. Ada dua aspek penting yang perlu dipertimbangkan: (i) bagaimana model bekerja secara individual dan (ii) bagaimana model bekerja sebagai suatu kelompok. Rata-rata banyak model sering kali lebih baik dibandingkan dengan pengamatan daripada model individual mana pun, karena kesalahan dalam merepresentasikan proses terperinci cenderung saling meniadakan dalam rata-rata multimodel. Sebagai contoh, FAQ 3.3 Gambar 1 membandingkan simulasi dari tiga generasi model terbaru (tersedia sekitar tahun 2008, 2013, dan 2021) dengan pengamatan tiga variabel iklim. Gambar tersebut menunjukkan korelasi antara pola yang disimulasikan dan diamati, dengan nilai 1 menunjukkan kesesuaian yang sempurna. Banyak model individual dari generasi baru yang berkinerja jauh lebih baik, sebagaimana ditunjukkan oleh nilai yang mendekati 1. Sebagai sebuah kelompok, setiap generasi mengungguli generasi sebelumnya: rata-rata multimodel (ditunjukkan oleh garis yang lebih panjang) secara progresif mendekati 1. Luas vertikal batang berwarna menunjukkan rentang kinerja model di setiap kelompok. Bagian atas batang bergerak ke atas dengan setiap generasi, yang menunjukkan peningkatan kinerja model dengan kinerja terbaik dari satu generasi ke generasi berikutnya. Dalam kasus presipitasi, kinerja model dengan kinerja terburuk serupa dalam dua generasi model terbaru, yang meningkatkan penyebaran antar model. Perkembangan dalam model iklim generasi terbaru, termasuk representasi proses fisik, kimia, dan biologi yang baru dan lebih baik, serta resolusi yang lebih tinggi, telah meningkatkan simulasi banyak aspek sistem Bumi. Simulasi ini, bersama dengan evaluasi kemampuan model untuk mensimulasikan pemanasan masa lalu serta penilaian terbar ...
# Score: 0.598, Q: Apakah Model Iklim Semakin Baik, dan Bagaimana Kita Mengetahuinya?, A: Model iklim adalah program komputer yang sangat canggih yang merangkum pemahaman kita tentang sistem iklim dan mensimulasikan, dengan kesetiaan sebanyak yang memungkinkan saat ini, interaksi kompleks antara atmosfer, lautan, permukaan tanah, salju dan es, ekosistem global, dan berbagai proses kimia dan biologis. Kompleksitas model iklim—representasi proses fisik seperti awan, interaksi permukaan tanah, dan representasi siklus karbon dan sulfur global dalam banyak model—telah meningkat secara substansial sejak Laporan Penilaian Pertama IPCC pada tahun 1990, jadi dalam hal itu, Model Sistem Bumi saat ini jauh lebih 'baik' daripada model-model pada era itu. Perkembangan ini berlanjut sejak Penilaian Keempat, sementara faktor-faktor lain juga berkontribusi pada peningkatan model. Superkomputer yang lebih canggih memungkinkan model saat ini untuk menyelesaikan detail spasial yang lebih halus. Model-model saat ini juga mencerminkan pemahaman yang lebih baik tentang bagaimana proses iklim bekerja—pemahaman itu berasal dari penelitian dan analisis yang sedang berlangsung, bersama dengan pengamatan baru dan yang lebih baik. Model iklim saat ini, pada prinsipnya, lebih baik daripada pendahulunya. Namun, setiap penambahan kompleksitas, meskipun dimaksudkan untuk meningkatkan beberapa aspek simulasi iklim, juga memperkenalkan sumber baru kemungkinan kesalahan (misalnya, melalui parameter yang tidak pasti) dan interaksi baru antara komponen model yang mungkin, meskipun hanya sementara, menurunkan simulasi model terhadap aspek lain dari sistem iklim. Lebih jauh, terlepas dari kemajuan yang telah dibuat, ketidakpastian ilmiah mengenai detail banyak proses tetap ada. Pertimbangan penting adalah bahwa kinerja model hanya dapat dievaluasi relatif terhadap pengamatan masa lalu, dengan mempertimbangkan variabilitas internal alami. Untuk memiliki keyakinan pada proyeksi masa depan model tersebut, iklim historis—dan variabilitas serta perubahannya—harus disimulasikan dengan baik. Cakupan evaluasi model, dalam hal jenis dan kuantitas pengamatan yang tersedia, ketersediaan eksperimen model yang lebih terkoordinasi, dan perluasan penggunaan berbagai metrik kinerja, telah memberikan informasi yang jauh lebih kuantitatif tentang kinerja model. Namun, ini saja mungkin tidak cukup. Sementara prediksi cuaca dan iklim musiman dapat diverifikasi secara berkala, proyeksi iklim yang mencakup satu abad atau lebih tidak dapat. Hal ini khususnya terjadi karena pemaksaan antropogenik mendorong sistem iklim ke arah kondisi yang sebelumnya tidak diamati dalam catatan instrumental, dan hal ini akan selalu menjadi keterbatasan. Mengukur kinerja model merupakan topik yang telah ditampilkan dalam semua Laporan Kelompok Kerja I IPCC sebelumnya. Membaca kembali penilaian sebelumnya ini memberikan gambaran umum tentang perbaikan yang telah dilakukan. Laporan sebelumnya biasanya memberikan survei yang cukup luas tentang kinerja model, yang menunjukkan perbedaan antara versi yang dihitung model dari berbagai kuantitas iklim dan estimasi observasional yang sesuai. Tidak dapat dihindari, beberapa model berkinerja lebih baik daripada yang lain untuk variabel iklim tertentu, tetapi tidak ada model individual yang secara jelas muncul sebagai 'yang terbaik' secara keseluruhan. Baru-baru ini, telah terjadi kemajuan dalam menghitung berbagai metrik kinerja, yang mensintesis kinerja model relatif terhadap berbagai observasi yang berbeda menurut skor numerik sederhana. Tentu saja, definisi skor tersebut, bagaimana cara menghitungnya, observasi yang digunakan (yang memiliki ketidakpastiannya sendiri), dan cara menggabungkan berbagai skor semuanya penting, dan akan memengaruhi hasil akhirnya. Namun demikian, jika metrik dihitung secara konsisten, seseorang dapat membandingkan berbagai generasi model. Hasil perbandingan tersebut secara umum menunjukkan bahwa, meskipun setiap generasi menunjukkan renta ...
# Score: 0.557, Q: Bisakah kita mengandalkan model komputer untuk memprediksi perubahan iklim di masa depan?, A: Model komputer merupakan salah satu alat yang digunakan ilmuwan untuk memahami iklim dan membuat proyeksi tentang bagaimana iklim akan merespons perubahan seperti meningkatnya kadar gas rumah kaca. Model merupakan simulasi sistem iklim bumi baik di tingkat global maupun regional. Sistem iklim sangatlah kompleks, dan tidak ada model matematika yang dapat mencerminkan semua proses rumitnya dengan sangat rinci. Oleh karena itu, selalu ada perbedaan antara model dan kenyataan, dan wajar saja ketika menyajikan hasil model, untuk memperkirakan seberapa besar perbedaan ini. Meskipun demikian, para ilmuwan yakin bahwa model dapat memproyeksikan perubahan gambaran besar seperti kenaikan suhu global. IPCC memberikan tiga alasan untuk keyakinannya dalam pemodelan iklim skala besar: fakta bahwa dasar-dasar model didasarkan pada hukum fisika yang mapan; keberhasilan model dalam memprediksi atau mereproduksi pola dan variabilitas yang diamati dalam iklim kita saat ini dan terkini; dan keberhasilan model dalam mereproduksi perubahan iklim kita di masa lalu, termasuk perubahan suhu global. Membandingkan model yang dikembangkan secara independen oleh berbagai pusat di seluruh dunia memberikan keyakinan tambahan jika model-model tersebut sepakat tentang responsnya (biasanya pada skala global dan benua). Untuk meminimalkan dampak ketidakakuratan dalam satu model, para ilmuwan dapat mensimulasikan skenario yang sama dalam beberapa model dan membandingkan hasilnya. Ketika model digunakan untuk memberikan informasi tentang bagian iklim yang lebih lokal – misalnya, di negara atau wilayah tertentu – hasilnya menjadi lebih tidak pasti. Namun, kualitas model regional meningkat, sehingga meningkatkan keyakinan mereka dalam memprediksi fitur lokal seperti curah hujan.
# Score: 0.509, Q: Suhu Bumi Pernah Berubah Sebelumnya. Bagaimana Pemanasan Global Saat Ini Berbeda?, A: Meskipun iklim dapat dicirikan oleh banyak variabel, suhu merupakan indikator utama dari keseluruhan kondisi iklim, dan suhu permukaan global sangat penting untuk mengkarakterisasi dan memahami perubahan iklim global, termasuk anggaran energi Bumi. Berbagai macam bukti geologis menunjukkan bahwa suhu telah berubah sepanjang sejarah Bumi. Berbagai arsip alam dari seluruh planet, seperti sedimen laut dan danau, es gletser, dan lingkaran pohon, menunjukkan bahwa ada saat-saat di masa lalu ketika planet ini lebih dingin, dan saat-saat ketika lebih hangat. Sementara keyakinan kita dalam mengukur perubahan suhu skala besar umumnya menurun semakin jauh ke belakang dalam waktu yang kita lihat, para ilmuwan masih dapat mengidentifikasi setidaknya empat perbedaan utama antara pemanasan baru-baru ini dan yang terjadi di masa lalu. Pemanasan terjadi hampir di mana-mana. Selama beberapa dekade dan abad dalam 2000 tahun terakhir, beberapa wilayah menghangat lebih dari rata-rata global sementara, pada saat yang sama, wilayah lain mendingin. Misalnya, antara abad ke-10 dan ke-13, wilayah Atlantik Utara menghangat lebih dari banyak wilayah lainnya. Sebaliknya, pola pemanasan permukaan baru-baru ini secara global lebih seragam daripada fluktuasi iklim dekade hingga seratus tahun lainnya selama setidaknya dua milenium terakhir. Ini memanas dengan cepat. Selama 2 juta tahun terakhir, iklim Bumi telah berfluktuasi antara periode interglasial yang relatif hangat dan periode glasial yang lebih dingin, ketika lapisan es tumbuh di wilayah yang luas di benua utara. Interval pemanasan yang cepat bertepatan dengan runtuhnya lapisan es utama, yang mengabarkan periode interglasial seperti Zaman Holosen saat ini, yang dimulai sekitar 12.000 tahun yang lalu. Selama peralihan dari periode glasial terakhir ke interglasial saat ini, peningkatan suhu total sekitar 5 °C. Perubahan itu memakan waktu sekitar 5000 tahun, dengan laju pemanasan maksimum sekitar 1,5 °C per seribu tahun, meskipun transisinya tidak mulus. Sebaliknya, permukaan Bumi telah menghangat sekitar 1,1 °C sejak 1850–1900. Namun, bahkan rekonstruksi terbaik dari suhu permukaan global selama periode deglasial terakhir terlalu kasar diselesaikan untuk perbandingan langsung dengan periode sesingkat 150 tahun terakhir. Tetapi selama 2000 tahun terakhir, kami memiliki catatan resolusi lebih tinggi yang menunjukkan bahwa laju pemanasan global selama 50 tahun terakhir telah melampaui laju periode 50 tahun lainnya. Pemanasan baru-baru ini membalikkan tren pendinginan global jangka panjang. Setelah periode glasial besar terakhir, suhu permukaan global mencapai puncaknya sekitar 6500 tahun yang lalu, kemudian perlahan mendingin. Tren pendinginan jangka panjang diselingi oleh dekade dan abad yang lebih hangat. Fluktuasi ini kecil dibandingkan dengan pemanasan yang terus-menerus dan menonjol yang dimulai pada pertengahan abad ke-19 ketika tren pendinginan skala milenium terbalik. Sudah lama sejak saat ini hangat. Dirata-ratakan di seluruh dunia, suhu permukaan dekade terakhir mungkin lebih hangat daripada ketika tren pendinginan panjang dimulai sekitar 6500 tahun yang lalu. Jika demikian, kita perlu melihat kembali setidaknya ke periode interglasial sebelumnya, sekitar 125.000 tahun yang lalu, untuk menemukan bukti suhu permukaan global multi-centennial yang lebih hangat daripada sekarang. Fluktuasi suhu sebelumnya disebabkan oleh proses alami berskala besar, sedangkan pemanasan saat ini sebagian besar disebabkan oleh manusia (lihat, misalnya, FAQ 1.3, FAQ 3.1). Namun, memahami bagaimana dan mengapa suhu telah berubah di masa lalu sangat penting untuk memahami pemanasan saat ini dan bagaimana pengaruh manusia dan alam akan berinteraksi untuk menentukan apa yang terjadi di masa depan. Mempelajari perubahan iklim masa lalu juga memperjelas bahwa, tidak seperti perubahan iklim sebelumnya, efek pemanasan baru-ba ...
#
#
# Query: 'apa yang perlu diketahui manusia dalam adaptasi terhadap dampak bahaya  iklim'
# Score: 0.625, Q: Bagaimana manusia beradaptasi terhadap dampak perubahan iklim dan apa saja batasan adaptasi yang diketahui?, A: Jika kita ingin mengatasi bahaya iklim dan mengurangi risiko bagi manusia dan ekosistem yang berasal dari perubahan iklim, kita harus beradaptasi. Kesadaran akan risiko iklim dan tindakan untuk menguranginya telah meningkat secara global, tetapi kemajuannya tidak merata dan laporan kami menyoroti kesenjangan besar antara tindakan adaptasi yang diambil dan apa yang dibutuhkan di banyak wilayah. Kesenjangan ini disebabkan oleh misalnya kurangnya pendanaan, komitmen politik, informasi yang dapat diandalkan, dan rasa urgensi. Hal ini menyebabkan orang-orang dan ekosistem yang paling rentan menjadi yang paling terdampak oleh perubahan iklim. Selain itu, laporan tersebut mengklarifikasi: adaptasi sangat penting untuk mengurangi kerusakan, tetapi jika ingin efektif, adaptasi harus berjalan seiring dengan pengurangan emisi gas rumah kaca yang ambisius karena dengan meningkatnya pemanasan, efektivitas banyak opsi adaptasi menurun. Karena perubahan iklim, dunia mengalami suhu yang lebih tinggi, naiknya permukaan laut, dan peningkatan kejadian ekstrem yang berdampak pada kehidupan di darat dan di lautan. Untuk mengatasi perubahan ini dan menghindari kerugian dan kerusakan yang drastis, manusia dan alam harus beradaptasi. Bagi tumbuhan dan hewan, ini berarti menyesuaikan diri dengan perubahan iklim dan dampaknya dengan menghabiskan lebih banyak waktu dan energi untuk tindakan yang dapat mempertahankan hidup (seperti mengatur suhu tubuh, memilih tempat yang lebih dingin, atau tetap terhidrasi) atau, jika memungkinkan, pindah ke wilayah yang kondisi lingkungannya masih dalam kisaran iklim yang biasa dialami organisme. Bagi manusia dan masyarakat, adaptasi terhadap perubahan iklim berarti menyesuaikan perilaku kita (misalnya tempat yang kita pilih untuk tinggal; cara kita merencanakan kota dan permukiman kita) dan mengadaptasi infrastruktur kita (misalnya penghijauan daerah perkotaan untuk penyimpanan air) untuk menghadapi perubahan iklim - saat ini dan di masa mendatang. Adaptasi yang berhasil memerlukan analisis risiko yang disebabkan oleh perubahan iklim dan penerapan tindakan yang tepat waktu untuk mengurangi risiko tersebut. Itulah alasan mengapa penulis IPCC mengajukan lima pertanyaan saat menilai kemajuan dalam adaptasi iklim secara regional dan global: 1) Apakah ada kesadaran bahwa perubahan iklim menyebabkan risiko? 2) Apakah tingkat risiko iklim saat ini dan di masa mendatang sedang dinilai? 3) Apakah tindakan adaptasi untuk mengurangi risiko ini telah dikembangkan dan dimasukkan dalam perencanaan? 4) Apakah tindakan adaptasi tersebut sedang dilaksanakan? 5) Apakah implementasi dan efektivitasnya dalam mengurangi risiko dipantau dan dievaluasi? Dalam Laporan Kelompok Kerja II kami, kami menyimpulkan bahwa kesadaran dan penilaian risiko iklim saat ini dan masa depan telah meningkat di seluruh dunia. Pemerintah nasional dan daerah serta perusahaan dan masyarakat sipil mengakui meningkatnya kebutuhan akan adaptasi. Setidaknya 170 negara dan banyak kota kini telah memasukkan adaptasi dalam kebijakan iklim dan proses perencanaan mereka. Proyek percontohan dan eksperimen lokal sedang dilaksanakan di berbagai sektor. Namun, mengingat tingkat dan cakupan dampak perubahan iklim, tindakan untuk menilai dan mengomunikasikan risiko, serta melaksanakan adaptasi tidaklah memadai. Misalnya, respons terkait adaptasi saat ini di semua sektor dan wilayah didominasi oleh modifikasi kecil pada praktik atau tindakan yang biasa dilakukan untuk menangani peristiwa cuaca ekstrem – yang sering kali hanya memungkinkan pengurangan risiko yang kecil atau terbatas secara lokal. Meskipun ini mungkin cukup dalam jangka pendek, risiko jangka panjang mungkin memerlukan perubahan yang lebih luas dan transformatif dalam perilaku dan infrastruktur kita. Singkatnya: ambisi, cakupan, dan kemajuan dalam mengurangi risiko iklim meningkat, tetap ...
# ...
# Score: 0.544, Q: Seberapa hangatkah suhu bumi nanti?, A: Tidak seorang pun dapat mengatakan dengan tepat seberapa hangat planet ini akan terjadi selama beberapa tahun, dekade, dan abad mendatang. Sebagian karena fakta sederhana bahwa tidak mungkin untuk mengetahui berapa banyak gas rumah kaca yang akan dipancarkan manusia di masa depan. Namun, itu juga karena para ilmuwan tidak dapat memprediksi dengan tepat seberapa "sensitif" atmosfer terhadap emisi tersebut. Ada juga area ketidakpastian lainnya, seperti kemungkinan perubahan di masa depan pada tingkat penyerapan karbon dioksida oleh lautan dan daratan dari atmosfer, dan berbagai siklus umpan balik yang dapat mempercepat pemanasan yang disebabkan oleh emisi buatan manusia. Karena hal-hal yang tidak diketahui ini, para ilmuwan biasanya memberikan berbagai kemungkinan perubahan suhu di masa depan untuk setiap skenario emisi. Dalam penilaian sains terbarunya, Panel Antarpemerintah tentang Perubahan Iklim (IPCC) PBB meneliti berbagai skenario emisi. Dalam skenario di mana peningkatan emisi gas rumah kaca tidak mendatar hingga akhir abad ini, perkiraan terbaik kenaikan suhu pada tahun 2100 adalah 4,0C, dengan "kisaran kemungkinan" 2,4–6,4C. Sebaliknya, dalam skenario di mana emisi diturunkan dengan sangat cepat, estimasi terbaik adalah 1,8 derajat, dengan kisaran kemungkinan 1,1–2,9C. Karena inersia dalam sistem iklim dan umur panjang beberapa gas rumah kaca di atmosfer, para ilmuwan memperkirakan bahwa dunia akan terus menghangat secara substansial – sekitar 0,6C lebih jauh – bahkan jika manusia benar-benar berhenti mengeluarkan gas rumah kaca saat ini. Seberapa pun suhu meningkat, akan tetap ada variasi regional, seperti yang diperjelas oleh peta Met Office tentang dunia setelah kenaikan 4C ini.
#
#
# Query: 'apa yang terjadi pada kehidupan anak-anak di masa depan apabila tidak ada aksi cepat dalam mengurangi gas emisi rumah kaca'
# Score: 0.695, Q: Bagaimana perubahan iklim akan mempengaruhi kehidupan anak-anak saat ini di masa mendatang, jika tidak ada tindakan segera yang diambil?, A: Dampak perubahan iklim semakin terasa di semua wilayah di dunia dengan meningkatnya tantangan untuk ketersediaan air, produksi pangan, dan mata pencaharian jutaan orang. Kita juga tahu bahwa dampaknya akan terus meningkat jika pemotongan drastis emisi gas rumah kaca ditunda lebih lanjut – yang memengaruhi kehidupan anak-anak saat ini di masa mendatang dan anak-anak mereka jauh lebih banyak daripada kita. Namun, sains juga jelas: dengan tindakan segera sekarang, dampak drastis masih dapat dicegah. Penilaian ilmiah dalam Laporan WGII ​​membahas jangka pendek (hingga 2040), jangka menengah (2041-2060) dan jangka panjang (2081-2100). Saat ini, dua tonggak terakhir mungkin tampak jauh, tetapi anak-anak yang lahir pada tahun 2020 akan berusia 20 tahun pada tahun 2040 dan berusia 80 tahun pada tahun 2100. Akhir abad ini kurang dari seumur hidup lagi. Tindakan yang diambil sekarang untuk mengurangi emisi gas rumah kaca yang memerangkap panas secara drastis dan beradaptasi dengan perubahan iklim akan berdampak besar pada kualitas hidup mereka dan kehidupan anak-anak mereka, serta kesehatan, kesejahteraan, dan keamanan mereka. Kita juga harus memperhitungkan bahwa pada tahun 2050 hampir 70% dari populasi dunia yang terus bertambah akan tinggal di daerah perkotaan, banyak di antaranya di permukiman yang tidak direncanakan atau informal. Akibatnya, anak-anak saat ini dan generasi mendatang lebih mungkin terpapar dan rentan terhadap perubahan iklim dan risiko terkait seperti banjir, tekanan panas, kelangkaan air, kemiskinan, dan kelaparan. Anak-anak termasuk yang paling menderita, seperti yang kita lihat saat ini. Namun, seperti apa masa depan anak-anak kita, jika kita tidak membatasi pemanasan global hingga jauh di bawah 2°C, lebih baik hingga 1,5°C, dibandingkan dengan suhu pra-industri? Berdasarkan penilaian Kelompok Kerja II, kita tahu bahwa pemanasan global telah mengubah sebagian besar dunia seperti yang kita ketahui. Dampaknya akan semakin intensif dalam beberapa dekade mendatang dengan implikasi yang mendalam bagi semua aspek kehidupan manusia di seluruh dunia. Persediaan makanan dan air kita, kota-kota kita, infrastruktur dan ekonomi serta kesehatan dan kesejahteraan kita akan terpengaruh. Misalnya: anak-anak berusia sepuluh tahun atau lebih muda pada tahun 2020 diproyeksikan akan mengalami peningkatan hampir empat kali lipat dalam kejadian ekstrem di bawah pemanasan global 1,5 ° C pada tahun 2100, dan peningkatan lima kali lipat di bawah pemanasan 3 ° C. Peningkatan paparan tersebut tidak akan dialami oleh seseorang yang berusia 55 tahun pada tahun 2020 dalam sisa hidup mereka di bawah skenario pemanasan apa pun. Secara global, persentase populasi yang terpapar stres panas yang mematikan diproyeksikan akan meningkat dari 30% saat ini menjadi 48-76% pada akhir abad ini, tergantung pada tingkat pemanasan dan lokasi di masa depan. Jika dunia menghangat lebih dari 4°C pada tahun 2100, jumlah hari dengan kondisi stres iklim bagi pekerja luar ruangan akan meningkat hingga 250 hari kerja per tahun pada akhir abad ini di beberapa bagian Asia Selatan, Afrika sub-Sahara tropis, dan sebagian Amerika Tengah dan Selatan. Hal ini akan menyebabkan konsekuensi negatif seperti berkurangnya produksi pangan dan harga pangan yang lebih tinggi. Di Eropa, jumlah orang yang berisiko mengalami stres panas akan meningkat dua hingga tiga kali lipat pada pemanasan global 3°C dibandingkan dengan tingkat pemanasan 1,5°C. Dengan pemanasan global yang sedang berlangsung, anak-anak saat ini di Asia Selatan dan Tenggara akan menyaksikan peningkatan kerugian di permukiman dan infrastruktur pesisir karena banjir yang disebabkan oleh kenaikan permukaan laut yang tidak dapat dihindari, dengan kerugian yang sangat tinggi di kota-kota Asia Timur. Pada pertengahan abad ini, lebih dari satu miliar orang yang tingga ...
# Score: 0.559, Q: Apakah kita memiliki kewajiban etis untuk menghentikan perubahan iklim?, A: Perubahan iklim akan merugikan generasi sekarang dan mendatang dengan membatasi akses mereka ke dunia yang aman dan sejahtera. Oleh karena itu, menghentikan perubahan iklim dapat dipandang sebagai kewajiban etis bagi generasi sekarang agar tidak merusak prospek generasi mendatang secara mendalam[1]. Konsep ‘keadilan’ juga diperdebatkan secara intens dalam negosiasi perubahan iklim internasional, karena pertanyaan tentang bagaimana mendistribusikan tanggung jawab untuk mengatasi perubahan iklim dalam banyak hal adalah tentang memutuskan apa yang ‘adil’ berdasarkan keadaan masing-masing negara, peran historis dalam menciptakan emisi, dan seberapa rentan mereka terhadap dampak perubahan iklim. Fakta bahwa generasi mendatang akan terpapar pada dampak perubahan iklim yang lebih parah - tetapi tidak dapat berpartisipasi dalam pengambilan keputusan saat ini tentang cara membatasi dan menghindari dampak masa depan tersebut - dapat dipandang sebagai pertanyaan tentang keadilan antargenerasi[2]. Ini adalah gagasan bahwa karena pilihan kita saat ini memiliki kekuatan untuk memengaruhi opsi dan kemungkinan yang tersedia bagi generasi mendatang, kita berkewajiban untuk mempertimbangkan dampak masa depan dari pilihan tersebut. Kegagalan untuk mengurangi emisi gas rumah kaca saat ini berarti generasi mendatang tidak punya pilihan selain menghadapi dampak iklim yang parah dan berbahaya di masa depan. Kaum muda di seluruh dunia telah memprotes distribusi yang tidak adil ini melalui aksi mogok sekolah global. Tulisan-tulisan keagamaan, seperti dari Paus dan para pemimpin Islam, juga telah menunjukkan bahwa sebagai manusia adalah pengelola Bumi, kita bertanggung jawab untuk melindunginya sebagai rumah bersama bagi generasi sekarang dan mendatang[3],[4]. Selain itu, negosiasi iklim internasional telah mempertimbangkan perlunya keadilan antara negara-negara berkembang dan negara-negara maju dalam bertindak atas perubahan iklim. Perjanjian Paris menyatakan bahwa Para Pihak dipandu oleh “prinsip kesetaraan dan tanggung jawab bersama tetapi berbeda serta kemampuan masing-masing, mengingat keadaan nasional yang berbeda”. Perjanjian ini juga mengakui “kebutuhan khusus dan keadaan khusus Para Pihak negara berkembang, terutama mereka yang sangat rentan terhadap dampak buruk perubahan iklim”[5]. Memutuskan distribusi tanggung jawab yang adil telah menjadi perdebatan dalam negosiasi iklim. Beberapa negara, seperti Inggris, telah memberikan kontribusi besar terhadap emisi global sejak dimulainya revolusi industri, sementara yang lain, seperti India, baru-baru ini menjadi penghasil emisi utama. Perbedaan ini menciptakan rasa ketidakadilan yang kuat di negara-negara berkembang, jika mereka percaya bahwa mereka diminta untuk memberikan kontribusi yang sama untuk mengurangi emisi seperti negara-negara dengan tanggung jawab historis yang lebih besar untuk emisi; dan yang juga lebih kaya karena pembangunan dan pertumbuhan ekonomi yang menyebabkan emisi ini[6]. Melampaui tanggung jawab historis, gagasan tentang 'kemampuan' adalah cara lain untuk menentukan distribusi tindakan yang adil antar negara. Pendekatan ini menunjukkan negara-negara yang paling mampu secara finansial atau teknologi harus bertanggung jawab untuk bertindak paling mendesak untuk mengurangi emisi. Hal ini memberi negara-negara yang kurang mampu tanggung jawab yang lebih kecil untuk segera menurunkan emisi, dan merupakan alasan lain beberapa orang menyarankan bahwa adil bagi negara-negara industri untuk memimpin upaya mengatasi perubahan iklim. Baik tanggung jawab historis Inggris yang besar untuk menyebabkan perubahan iklim dan kemampuannya yang kuat untuk bertindak - sebagai negara yang kaya dan maju - adalah di antara alasan mengapa Komite Perubahan Iklim menyarankan bahwa adil bagi Inggris untuk mencapai emisi nol bersih gas rumah kaca pada tahun 2050[7].
# Score: 0.498, Q: Apakah sudah terlambat untuk mencegah perubahan iklim?, A: Manusia telah menyebabkan perubahan iklim yang besar, dan kita telah memulai lebih banyak perubahan lagi. Bahkan jika kita berhenti mengeluarkan gas rumah kaca hari ini, pemanasan global akan terus terjadi setidaknya selama beberapa dekade lagi, bahkan berabad-abad.
# Score: 0.457, Q: Berapa banyak waktu yang kita miliki untuk menghentikan perubahan iklim?, A: Sebenarnya tidak ada batas waktu yang pasti antara aksi iklim dan tidak adanya aksi. Beberapa penelitian dan artikel menunjukkan bahwa kecuali kita membuat kemajuan signifikan menuju dekarbonisasi (mengurangi karbon dari atmosfer dan mengganti bahan bakar fosil dalam perekonomian kita) pada tahun 2030, kita mungkin akan menghadapi dampak iklim yang dahsyat yang akan membanjiri masyarakat kita dan menimbulkan ancaman eksistensial bagi ekosistem tertentu. Tidak ada garis demarkasi pasti yang dapat kita lindungi, sebaliknya ini adalah masalah meminimalkan dampak perubahan iklim. Setiap hari yang berlalu, kita melepaskan karbon ke atmosfer dan meningkatkan risiko planet kita. Sebagian besar ilmuwan setuju bahwa kita perlu mulai mengurangi emisi karbon SEKARANG JUGA untuk memberikan planet kita dan populasi kita masa depan yang paling tidak terdampak.
# Score: 0.386, Q: Faktor-faktor apa yang relevan dalam mempertimbangkan tanggung jawab atas tindakan masa depan yang akan mengurangi perubahan iklim?, A: Sulit untuk menunjukkan dengan jelas seberapa besar tanggung jawab yang harus diambil oleh berbagai pihak untuk mengurangi emisi di masa mendatang. Pendapatan dan kapasitas relevan, seperti halnya persepsi etika tentang hak dan keadilan. Seseorang mungkin juga menyelidiki bagaimana masalah serupa telah ditangani di masa lalu dalam konteks non-iklim. Di bawah sistem hukum umum dan hukum perdata, mereka yang bertanggung jawab atas tindakan berbahaya hanya dapat dimintai pertanggungjawaban jika tindakan mereka melanggar standar hukum, seperti kelalaian atau gangguan. Kelalaian didasarkan pada standar orang yang masuk akal. Di sisi lain, tanggung jawab untuk menyebabkan gangguan tidak ada jika aktor tidak tahu atau memiliki alasan untuk mengetahui dampak dari perilakunya. Jika ditetapkan bahwa emisi GRK merupakan perilaku yang salah dalam ketentuan hukum, sifat hubungan kausal dengan kerugian yang dihasilkan kemudian harus dibuktikan.

# %%
# Jawaban benar untuk setiap query berdasarkan kolom 'kueri' dan 'question' pada DataFrame queries_pd
correct_answers = {row['kueri']: row['question'] for _, row in queries_pd.iloc[0:11].iterrows()}


rows = []
for query, result_list in results.items():
    correct_answer = correct_answers[query]
    rank = 0
    questions = []

    # Menyimpan 5 pertanyaan per query
    for i, res in enumerate(result_list[:5]):
        questions.append(f"{i + 1}. {res['question']}")
        if res["question"] == correct_answer:
            rank = i + 1

    reciprocal_rank = 1 / rank if rank > 0 else 0

    question_text = "\n".join(questions)

    rows.append({
        "Query": query,
        "Questions": question_text,
        "Rank": rank,
        "Reciprocal Rank": reciprocal_rank,
    })

mrr_df = pd.DataFrame(rows)

# Menghitung MRR secara keseluruhan
mrr_overall = mrr_df["Reciprocal Rank"].mean()

print(mrr_df)
print(f"\nMean Reciprocal Rank (MRR): {mrr_overall:.3f}")
# Out:
#                                                Query  \
# 0  apa yang bisa kita pelajari dari iklim di masa...
# 1  kapan dampak aktivitas manusia terhadap iklim ...
# 2              apakah model iklim semakin berkembang
# 3  apa yang perlu diketahui manusia dalam adaptas...
# 4  kenapa kota-kota yang berada di sekitar tepi l...
# 5  apakah ada pengaruh terhadap rotasi planet apa...
# 6  apa kontribusi yang bisa saya lakukan dalam me...
# 7  bagaimana peluang dan tantangan dalam mitigasi...
# 8  cara mengetahui sehangat dan sedingin apa cuac...
# 9  apa yang terjadi pada kehidupan anak-anak di m...
#
#                                            Questions  Rank  Reciprocal Rank
# 0  1. Apa yang Dapat Diajarkan Iklim Masa Lalu ke...     1              1.0
# 1  1. Kapan Pengaruh Manusia terhadap Iklim Menja...     1              1.0
# 2  1. Mengapa Begitu Banyak Model dan Skenario ya...     2              0.5
# 3  1. Apa itu adaptasi perubahan iklim?\n2. Bagai...     2              0.5
# 4  1. Mengapa kota-kota pesisir dan pemukiman di ...     1              1.0
# 5  1. Jika semua es di Bumi mencair dan mengalir ...     1              1.0
# 6  1. Apa yang dapat saya lakukan untuk menghenti...     1              1.0
# 7  1. Bagaimana peluang dan hambatan untuk mitiga...     1              1.0
# 8  1. Bagaimana kita tahu seberapa hangat atau di...     1              1.0
# 9  1. Bagaimana perubahan iklim akan mempengaruhi...     1              1.0
#
# Mean Reciprocal Rank (MRR): 0.900

# %%
mrr_df.to_excel('/content/drive/MyDrive/myData/dataset/hasil2.xlsx')

# %% [markdown]
# # upload model to hugging face

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.29.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.1.31)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_hub import create_repo

repo_name = "indosbert-climate-faq"
create_repo(repo_name, repo_type="model")
# Out:
# RepoUrl('https://huggingface.co/annisamukhri/indosbert-climate-faq', endpoint='https://huggingface.co', repo_type='model', repo_id='annisamukhri/indosbert-climate-faq')

# %%
from huggingface_hub import upload_folder

upload_folder(
    folder_path="/content/drive/MyDrive/myqas/models1/finetuned-indoSBERT-large-e5bs16",
    repo_id="annisamukhri/indosbert-climate-faq"
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/annisamukhri/indosbert-climate-faq/commit/8617564216ad34f4ebedff6237e2142dc1cfc5f8', commit_message='Upload folder using huggingface_hub', commit_description='', oid='8617564216ad34f4ebedff6237e2142dc1cfc5f8', pr_url=None, repo_url=RepoUrl('https://huggingface.co/annisamukhri/indosbert-climate-faq', endpoint='https://huggingface.co', repo_type='model', repo_id='annisamukhri/indosbert-climate-faq'), pr_revision=None, pr_num=None)
